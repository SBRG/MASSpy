# %%
from mass import MassReaction, MassMetabolite, MassModel
from mass.test import create_test_model
#Incorporates RBC Core Model as a test model
model= create_test_model("textbook")

# %%
# def attribute(obj):
#     "A portion of the class; classes program functions within the objects to comprise an attribute with the reaction model"
#     obj=dir(MassReaction)
#     [a for a in attributes if not(a[0].startswith('__')and a[0].endswith('__'))]
#     print(obj)
#     return;
#     pass
#    # a for a in attributes if not 
# obj=dir(MassReaction)
# print(obj)
# # [a for a in obj if not(a[0].startswith('__')and a[0].endswith('__'))]

# %%
dir(MassReaction(property))
# Out:
# ['Keq',
#  'Keq_str',
#  'S',
#  '__add__',
#  '__class__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__isub__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__weakref__',
#  '_associate_gene',
#  '_compartments',
#  '_dissociate_gene',
#  '_equilibrium_constant',
#  '_forward_rate_constant',
#  '_gene_reaction_rule',
#  '_genes',
#  '_gibbs_reaction_energy',
#  '_id',
#  '_lower_bound',
#  '_metabolites',
#  '_model',
#  '_repr_html_',
#  '_reverse_rate_constant',
#  '_reversible',
#  '_rtype',
#  '_set_id_with_model',
#  '_update_awareness',
# ...

# %%
# class MyClass(object):
#     a = '12'
#     b = '34'
#     def myfunc(self):
#         return self.a
# import inspect
# attributes = inspect.getmembers(MyClass, lambda a:not(inspect.isroutine(a)))
# print(attributes)

# %%
dir(MassReaction)
# Out:
# ['Keq',
#  'Keq_str',
#  'S',
#  '__add__',
#  '__class__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__isub__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__weakref__',
#  '_associate_gene',
#  '_dissociate_gene',
#  '_repr_html_',
#  '_set_id_with_model',
#  '_update_awareness',
#  'add_metabolites',
#  'all_parameter_ids',
#  'build_reaction_from_string',
#  'build_reaction_string',
#  'check_mass_balance',
#  'compartments',
#  'copy',
#  'equilibrium_constant',
#  'exchange',
#  'external_metabolite',
#  'flux_symbol',
# ...

# %%
dir(MassReaction(property))
# Out:
# ['Keq',
#  'Keq_str',
#  'S',
#  '__add__',
#  '__class__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__isub__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__weakref__',
#  '_associate_gene',
#  '_compartments',
#  '_dissociate_gene',
#  '_equilibrium_constant',
#  '_forward_rate_constant',
#  '_gene_reaction_rule',
#  '_genes',
#  '_gibbs_reaction_energy',
#  '_id',
#  '_lower_bound',
#  '_metabolites',
#  '_model',
#  '_repr_html_',
#  '_reverse_rate_constant',
#  '_reversible',
#  '_rtype',
#  '_set_id_with_model',
#  '_update_awareness',
# ...

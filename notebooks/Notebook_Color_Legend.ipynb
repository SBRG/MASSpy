# %% [markdown]
# # Notebook Color Legend:
#
# The following table provides the descriptions for color codes utilized throughout the markdown cells in the iPython notebooks.
#
# <table border = "1", width="100%", height="100%">
#   <tr>
#     <th width="25%">Description</th>
#     <th width="15%">Color Name (Emphasis)</th>
#     <th width="50%">Example</th>
#     <th width="10%">Hex #</th>
#   </tr><tr>
#     <td>Name of the Python package</td>
#     <td><b>Black (Bold)</b></td>
#     <td><b>masspy</b></td>
#     <td>#000000</td>
#   </tr><tr>
#     <td>The <font color=#0000FF>mass</font> module and related submodules in <b>masspy</b></td>
#     <td><font color=#0000FF>Blue</font></td>
#     <td><font color=#0000FF>mass.util</font></td>
#     <td>#0000FF</td>
#   </tr><tr>
#     <td>A class or object from <b>masspy</b></td>
#     <td><font color=#4682B4>Steel Blue</font></td>
#     <td><font color=#0000FF>mass</font><font color=#4682B4>.MassModel</font></td>
#     <td>#4682B4</td>
#   <tr>
#     <td>A class get or set attribute method, or a class property, for an object from <b>masspy</b></td>
#     <td><font color=#1E90FF>Dodger Blue</font></td>
#     <td><font color=#0000FF>mass</font><font color=#4682B4>.MassModel</font><font color=#1E90FF>.metabolites</font></td>
#     <td>#1E90FF</td>
#   </tr><tr>
#     <td>A class method or a function from <b>masspy</b></td>
#     <td><font color=#00008B>Dark Blue</font></td>
#     <td><font color=#0000FF>mass</font><font color=#4682B4>.MassModel</font><font color=#00008B>.add_metabolites</font></td>
#     <td>#00008B</td>
#   </tr><tr>
#     <td>The <font color=#008000>cobra</font> module and related submodules in <b>cobrapy</b></td>
#     <td><font color=#008000>Green</font></td>
#     <td><font color=#008000>cobra.util</font></td>
#     <td>#008000</td>
#   </tr><tr>
#     <td>A class or object from <b>cobrapy</b></td>
#     <td><font color=#556B2F>Dark Olive Green</font></td>
#     <td><font color=#008000>cobra</font><font color=#556B2F>.Model</font></td>
#     <td>#556B2F</td>
#   <tr>
#     <td>A class get or set attribute methodd, or a class property, for an object from <b>cobrapy</b></td>
#     <td><font color=#8FBC8B>Dark Sea Green</font></td>
#     <td><font color=#008000>cobra</font><font color=#556B2F>.Model</font><font color=#8FBC8B>.metabolites</font></td>
#     <td>#8FBC8B</td>
#   </tr><tr>
#     <td>A class method or a function from <b>cobrapy</b></td>
#     <td><font color=#006400>Dark Green</font></td>
#     <td><font color=#008000>cobra</font><font color=#556B2F>.Model</font><font color=#006400>.add_metabolites</font></td>
#     <td>#006400</td>
#   </tr><tr>
#     <td>Any package module excluding the <font color=#0000FF>mass</font> and <font color=#008000>cobra</font> modules
#     <td><font color=#800080>Purple</font></td>
#     <td><b>sympy</b><font color=#800080>.core</font></td>
#     <td>#800080</td>
#   </tr><tr>
#     <td>A class or object from any package excluding <b>masspy</b> and <b>cobrapy</b></td>
#     <td><font color=#9400D3>Dark Violet</font></td>
#     <td><b>sympy</b><font color=#9400D3>.Equality</font></td>
#     <td>#8A2BE2</td>
#   <tr>
#     <td>A class get or set attribute method, or a class property, for an object from any package excluding <b>masspy</b> and <b>cobrapy</b></td>
#     <td><font color=#FF00FF>Magenta</font></td>
#     <td><b>sympy</b><font color=#9400D3>.Equality</font><font color=#FF00FF>.rhs</font></td>
#     <td>#FF00FF</td>
#   </tr><tr>
#     <td>A class method or a function from any package excluding <b>masspy</b> and <b>cobrapy</b></td>
#     <td><font color=#8B008B>Dark Magenta</font></td>
#     <td><b>sympy</b><font color=#8B008B>.sympify</font></td>
#     <td>#8B008B</td>
#   </tr><tr>
#     <td>Any arg or kwarg for a class method or function</td>
#     <td><font color=#B22222>Firebrick Red</font></td>
#     <td><font color=#0000FF>mass</font><font color=#4682B4>.MassModel</font><font color=#00008B>.add_metabolites(</font><font color=#B22222>metabolite_list</font><font color=#00008B>)</font></td>
#     <td>#B22222</td>
#   </tr>
#
# </table>

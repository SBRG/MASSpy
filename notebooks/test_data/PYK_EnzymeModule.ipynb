# %% [markdown]
# # Pyruvate Kinase (PYK)
# To construct the pyruvate kinase module, first we import <b>masspy</b> and other essential packages. Constants used throughout the notebook are also defined.

# %%
from os import path

import matplotlib.pyplot as plt

from scipy import optimize

import sympy as sym

from cobra import DictList

from mass.analysis.linear import matrix_rank
from mass import MassMetabolite, Simulation, UnitDefinition, qcqa_model
from mass.enzyme_modules import EnzymeModule
from mass.io import json, sbml
from mass.util import Keq2k, k2Keq, strip_time

# %% [markdown]
# Note that the total enzyme concentration of PYK is \\(69 nM = 0.069 \mu M = 0.000069 mM\\).
#
# For the construction of the <font color=#4682B4>EnzymeModule</font> for PYK, the following assumptions were made:
#
# 1. The enzyme is a homotetramer.
# 2. The enzyme binding and catalyzation of substrates occurs in a random sequential mechanism.
# 3. The mechanism of allosteric regulation is based on the Monod-Wyman-Changeux (MWC) model for allosteric transitions of homoproteins.

# %% [markdown]
# ## Module Construction
# The first step of creating the PYK module is to define the <font color=#4682B4>EnzymeModule</font>. The <font color=#4682B4>EnzymeModule</font> is an extension of the <font color=#4682B4>MassModel</font>, with additional enzyme-specific attributes that aid in the construction, validation, and utilization of the module.
#
# __Note:__ All <font color=#4682B4>EnzymeModule</font> specific attributes start will start the prefix "enzyme" or "enzyme_module".

# %%
PYK = EnzymeModule("PYK", name="Pyruvate Kinase", subsystem="Glycolysis")

# %% [markdown]
# ### Metabolites
# #### Ligands
# The next step is to define all of the metabolites using the <font color=#4682B4>MassMetabolite</font> object. For <font color=#4682B4>EnzymeModules</font>, the <font color=#4682B4>MassMetabolite</font> objects will be refered to as ligands, for these <font color=#4682B4>MassMetabolite</font> form a complex with the enzyme to serve some biological purpose. Some considerations for this step include the following:
#
# 1. It is important to use a clear and consistent format for identifiers and names when defining the <font color=#4682B4>MassMetabolite</font> objects for various reasons, some of which include improvements to model clarity and utility, assurance of unique identifiers (required to add metabolites to the model), and consistency when collaborating and communicating with others.
#
#
# 2. In order to ensure our model is physiologically accurate, it is important to provide the <font color=#B22222>formula</font> argument with a string representing the chemical formula for each metabolite, and the <font color=#B22222>charge</font> argument with an integer representing the metabolite's ionic charge (Note that neutrally charged metabolites are provided with 0). These attributes can always be set later if necessary using the <font color=#1E90FF>formula</font> and <font color=#1E90FF>charge</font> attribute setter methods.
#
#
# 3. To indicate that the cytosol is the cellular compartment in which the reactions occur, the string "c" is provided to the <font color=#B22222>compartment</font> argument.
#
# This model will be created using identifiers and names found in the [BiGG Database](http://bigg.ucsd.edu/).
#
# The ligands correspond to the activators, inhibitors, cofactors, substrates, and products involved in the enzyme catalyzed reaction. In this model, there are 6 species which must be considered.

# %%
pep_c = MassMetabolite(
    id="pep_c",
    name="Phosphoenolpyruvate",
    formula="C3H2O6P",
    charge=-3,
    compartment="c")
pyr_c = MassMetabolite(
    id="pyr_c",
    name="Pyruvate",
    formula="C3H3O3",
    charge=-1,
    compartment="c")
fdp_c = MassMetabolite(
    id="fdp_c",
    name="D-Fructose 1,6-bisphosphate",
    formula="C6H10O12P2",
    charge=-4,
    compartment="c")
atp_c = MassMetabolite(
    id="atp_c",
    name="ATP",
    formula="C10H12N5O13P3",
    charge=-4,
    compartment="c")
adp_c = MassMetabolite(
    id="adp_c",
    name="ADP",
    formula="C10H12N5O10P2",
    charge=-3,
    compartment="c")
h_c = MassMetabolite(
    id="h_c",
    name="H+",
    formula="H",
    charge=1,
    compartment="c")

# %% [markdown]
# After generating the ligands, they are added to the <font color=#4682B4>EnzymeModule</font> through the <font color=#00008B>add_metabolites</font> method. The ligands of the <font color=#4682B4>EnzymeModule</font> can be viewed as a DictList through the <font color=#1E90FF>enzyme_module_ligands</font> attribute, or through user-defined categorizes using the <font color=#1E90FF>enzyme_module_ligands_categorized</font> attribute. Note that all of the ligands are originally categorized as undefined.

# %%
PYK.add_metabolites([pep_c, adp_c, fdp_c, atp_c, pyr_c, h_c])
# Access DictList of ligands and print
print("All {0} Ligands: {1}\n".format(
    PYK.id, "; ".join([m.id for m in PYK.enzyme_module_ligands])))
# Access categorized dict attribute for ligands and print
for category, ligands in PYK.enzyme_module_ligands_categorized.items():
    print("{0}: {1}".format(
        category, str([m.id for m in ligands])))
# Out:
# All PYK Ligands: pep_c; adp_c; fdp_c; atp_c; pyr_c; h_c
#
# Undefined: ['adp_c', 'atp_c', 'fdp_c', 'h_c', 'pep_c', 'pyr_c']

# %% [markdown]
# When metabolites are first added to an <font color=#4682B4>EnzymeModule</font>, they are placed in the "Undefined" category. The <font color=#1E90FF>enzyme_module_ligands_categorized</font> attribute can also be used to reassign metabolites to user-defined categories by providing a dictionary where keys are the categories and values are the metabolites. Note that any metabolite can be placed in more than one category.

# %%
PYK.enzyme_module_ligands_categorized =  {
    "Substrates": pep_c,
    "Cofactors": [adp_c, h_c],
    "Activators": [fdp_c],
    "Inhibitors": atp_c,
    "Products": [pyr_c, atp_c]}
# Access DictList of ligands and print
print("All {0} ligands ({1} total):\n{2}\n".format(
    PYK.id, len(PYK.enzyme_module_ligands), str([m.id for m in PYK.enzyme_module_ligands])))
# Access categorized dict attribute for ligands and print
for category, ligands in PYK.enzyme_module_ligands_categorized.items():
    print("{0}: {1}".format(
        category,str([m.id for m in ligands])))
# Out:
# All PYK ligands (6 total):
# ['pep_c', 'adp_c', 'fdp_c', 'atp_c', 'pyr_c', 'h_c']
#
# Substrates: ['pep_c']
# Cofactors: ['adp_c', 'h_c']
# Activators: ['fdp_c']
# Inhibitors: ['atp_c']
# Products: ['atp_c', 'pyr_c']

# %% [markdown]
# #### EnzymeModuleForms
#
# The next step is to define the various forms of the enzyme and enzyme-ligand complexes. These forms can be represented through an <font color=#4682B4>EnzymeModuleForm</font> object. Just like how <font color=#4682B4>EnzymeModules</font> extend <font color=#4682B4>MassModels</font>, the <font color=#4682B4>EnzymeModuleForms</font> extend <font color=#4682B4>MassMetabolites</font>, giving them the same functionality as a <font color=#4682B4>MassMetabolite</font>. However, there are three important additional attrubutes that are specific to the <font color=#4682B4>EnzymeModuleForm</font>.
#
# * The first attribute is the <font color=#1E90FF>enzyme_id</font>. It is meant to hold the identifier or name of the <font color=#4682B4>EnzymeModule</font> that the <font color=#4682B4>EnzymeModuleForm</font> belongs to.
# * The second and third attributes are the <font color=#1E90FF>bound_catalytic</font> and <font color=#1E90FF>bound_effectors</font> attributes, designed to contain metabolites bound to the active/catalytic site and effector metabolites bound to the enzyme, respectively.
# * Automatic generation of the <font color=#1E90FF>name</font>, <font color=#1E90FF>formula</font>, and <font color=#1E90FF>charge</font> attributes attributes utilize the <font color=#1E90FF>bound_catalytic</font> and <font color=#1E90FF>bound_effectors</font> attributes, which can aid in identification of <font color=#4682B4>EnzymeModuleForms</font> and mass and charge balancing of the reactions.
#
# The most convenient way to make an <font color=#4682B4>EnzymeModuleForm</font> is through the <font color=#4682B4>EnzymeModule</font><font color=#00008B>.make_enzyme_module_form</font> method. There are several reasons to use this method to generate the <font color=#4682B4>EnzymeModuleForms</font>:
#
# 1. The only requirement to creating an <font color=#4682B4>EnzymeModuleForm</font> is an identifier.
# 2. A string can optionally be provided for the <font color=#B22222>name</font> argument to set the corresponding <font color=#1E90FF>name</font> attribute, or it can automatically be generated and set by setting the string "Automatic" (case sensitve).
# 3. The <font color=#1E90FF>enzyme_id</font>, <font color=#1E90FF>formula</font> and <font color=#1E90FF>charge</font> attributes are set based on the identifier of the EnzymeModule and the MassMetabolite objects found in <font color=#1E90FF>bound_catalytic</font> and <font color=#1E90FF>bound_effectors</font>
# 4. Just like the <font color=#1E90FF>enzyme_module_ligands_categorized</font> attribute, there is the <font color=#1E90FF>enzyme_module_forms_categorized</font> attribute that behaves in a similar manner. Categories can be set at the time of construction by providing a string or a list of strings to the <font color=#B22222>categories</font> argument.
# 5. <font color=#4682B4>EnzymeModuleForms</font> are automatically added to the <font color=#4682B4>EnzymeModule</font> once created.
#
# For this module, there are 25 <font color=#4682B4>EnzymeModuleForms</font> that must be created. Because of the assumptions made for this module, a loop can be used to help automate the construction of the <font color=#4682B4>EnzymeModuleForms</font>.

# %%
# Number of identical subunits
n_subunits = 4

for i in range(n_subunits + 1):
    # Make enzyme forms per number of bound activators (Up to 4 Total)
    PYK.make_enzyme_module_form(
        id="pyk_R{0:d}_c".format(i), 
        name="Automatic", 
        categories="Relaxed", 
        bound_catalytic={},
        bound_effectors={fdp_c: i},
        compartment="c");

    PYK.make_enzyme_module_form(
        id="pyk_R{0:d}_A_c".format(i), 
        name="Automatic", 
        categories="Relaxed", 
        bound_catalytic={adp_c: 1},
        bound_effectors={fdp_c: i},
        compartment="c");
    
    PYK.make_enzyme_module_form(
        id="pyk_R{0:d}_P_c".format(i), 
        name="Automatic", 
        categories="Relaxed", 
        bound_catalytic={pep_c: 1},
        bound_effectors={fdp_c: i},
        compartment="c");
    
    PYK.make_enzyme_module_form(
        id="pyk_R{0:d}_AP_c".format(i), 
        name="Automatic", 
        categories="Relaxed", 
        bound_catalytic={adp_c: 1, pep_c: 1},
        bound_effectors={fdp_c: i},
        compartment="c");

    # Make enzyme forms per number of bound inhibitors (Up to 4 Total)
    PYK.make_enzyme_module_form(
        id="pyk_T{0:d}_c".format(i), 
        name="Automatic", 
        categories="Tense", 
        bound_catalytic={},
        bound_effectors={atp_c: i},
        compartment="c");
    
# Access DictList of EnzymeModuleForms and print
print("All {0} EnzymeModuleForms ({1} total):\n{2}\n".format(
    PYK.id, len(PYK.enzyme_module_forms), str([m.id for m in PYK.enzyme_module_forms])))
# Access categorized dict attribute for EnzymeModuleForms and print
for category, enz_forms in PYK.enzyme_module_forms_categorized.items():
    print("{0}: {1}\n".format(
        category, str([m.id for m in enz_forms])))
# Out:
# All PYK EnzymeModuleForms (25 total):
# ['pyk_R0_c', 'pyk_R0_A_c', 'pyk_R0_P_c', 'pyk_R0_AP_c', 'pyk_T0_c', 'pyk_R1_c', 'pyk_R1_A_c', 'pyk_R1_P_c', 'pyk_R1_AP_c', 'pyk_T1_c', 'pyk_R2_c', 'pyk_R2_A_c', 'pyk_R2_P_c', 'pyk_R2_AP_c', 'pyk_T2_c', 'pyk_R3_c', 'pyk_R3_A_c', 'pyk_R3_P_c', 'pyk_R3_AP_c', 'pyk_T3_c', 'pyk_R4_c', 'pyk_R4_A_c', 'pyk_R4_P_c', 'pyk_R4_AP_c', 'pyk_T4_c']
#
# Relaxed: ['pyk_R0_AP_c', 'pyk_R0_A_c', 'pyk_R0_P_c', 'pyk_R0_c', 'pyk_R1_AP_c', 'pyk_R1_A_c', 'pyk_R1_P_c', 'pyk_R1_c', 'pyk_R2_AP_c', 'pyk_R2_A_c', 'pyk_R2_P_c', 'pyk_R2_c', 'pyk_R3_AP_c', 'pyk_R3_A_c', 'pyk_R3_P_c', 'pyk_R3_c', 'pyk_R4_AP_c', 'pyk_R4_A_c', 'pyk_R4_P_c', 'pyk_R4_c']
#
# Tense: ['pyk_T0_c', 'pyk_T1_c', 'pyk_T2_c', 'pyk_T3_c', 'pyk_T4_c']

# %% [markdown]
# ## Reactions
# ### EnzymeModuleReactions
# Once all of the <font color=#4682B4>MassMetabolites</font> and <font color=#4682B4>EnzymeModuleForms</font> have been created, the next step is to define all of the enzyme-ligand binding reactions and conformation trasitions that occur in its mechanism.
#
# These reactions can be represented through an <font color=#4682B4>EnzymeModuleReaction</font> object. As with the previous enzyme objects,  <font color=#4682B4>EnzymeModuleReactions</font> extend <font color=#4682B4>MassReactions</font> to maintain the same functionality. However, as with the <font color=#4682B4>EnzymeModuleForms</font>, the <font color=#4682B4>EnzymeModuleReaction</font> has additional enzyme-specific attributes, such as the <font color=#1E90FF>enzyme_id</font>.
#
# The most conveient way to make an <font color=#4682B4>EnzymeModuleReaction</font> is through the <font color=#4682B4>EnzymeModule</font><font color=#00008B>.make_enzyme_module_reaction</font> method. There are several reasons to use this method to generate the EnzymeModuleReactions:
#
# 1. The only requirement to creating an <font color=#4682B4>EnzymeModuleReaction</font> is an identifier.
# 2. A string can optionally be provided for the <font color=#B22222>name</font> argument to set the corresponding <font color=#1E90FF>name</font> attribute, or it can automatically be generated and set by setting the string "Automatic" (case sensitve).
# 3. There is an <font color=#1E90FF>enzyme_module_reactions_categorized</font> attribute that behaves in a similar manner as the previous categorized dictionary attributes. Categories can be set at the time of construction by providing a string or a list of strings to the <font color=#B22222>categories</font> argument.
# 4. <font color=#4682B4>MassMetabolites</font> and <font color=#4682B4>EnzymeModuleForms</font> that already exist in the <font color=#4682B4>EnzymeModule</font> can be directly added to the newly created <font color=#4682B4>EnzymeModuleReaction</font> by providing a dictionary to the optional <font color=#B22222>metabolites_to_add</font> argument using string identifiers (or the objects) as keys and their stoichiometric coefficients as the values.
# 5. <font color=#4682B4>EnzymeModuleReactions</font> are automatically added to the <font color=#4682B4>EnzymeModule</font> once created.
#
# For this module, there are 34 <font color=#4682B4>EnzymeModuleReactions</font> that must be created. Because of the assumptions made for this module, a loop can be used to help automate the construction of the <font color=#4682B4>EnzymeModuleReactions</font>.

# %%
for i in range(n_subunits + 1):
    # Make reactions for enzyme-ligand binding and catalytzation per number of bound activators (Up to 4 Total)
    PYK.make_enzyme_module_reaction(
        id="PYK_R{0:d}1".format(i), 
        name="Automatic",
        subsystem="Glycolysis",
        reversible=True,
        categories="pep_c binding",
        metabolites_to_add={
            "pyk_R{0:d}_c".format(i): -1, 
            "pep_c": -1, 
            "pyk_R{0:d}_P_c".format(i): 1})
    
    PYK.make_enzyme_module_reaction(
        id="PYK_R{0:d}2".format(i), 
        name="Automatic",
        subsystem="Glycolysis",
        reversible=True,
        categories="adp_c binding",
        metabolites_to_add={
            "pyk_R{0:d}_c".format(i): -1, 
            "adp_c": -1, 
            "pyk_R{0:d}_A_c".format(i): 1})
    
    PYK.make_enzyme_module_reaction(
        id="PYK_R{0:d}3".format(i), 
        name="Automatic",
        subsystem="Glycolysis",
        reversible=True,
        categories="pep_c binding",
        metabolites_to_add={
            "pyk_R{0:d}_A_c".format(i): -1, 
            "pep_c": -1, 
            "pyk_R{0:d}_AP_c".format(i): 1})
    
    PYK.make_enzyme_module_reaction(
        id="PYK_R{0:d}4".format(i), 
        name="Automatic",
        subsystem="Glycolysis",
        reversible=True,
        categories="adp_c binding",
        metabolites_to_add={
            "pyk_R{0:d}_P_c".format(i): -1, 
            "adp_c": -1, 
            "pyk_R{0:d}_AP_c".format(i): 1})
    
    PYK.make_enzyme_module_reaction(
        id="PYK_R{0:d}5".format(i), 
        name="Automatic",
        subsystem="Glycolysis",
        reversible=False,
        categories="catalyzation",
        metabolites_to_add={
            "pyk_R{0:d}_AP_c".format(i): -1, 
            "h_c": -1, 
            "pyk_R{0:d}_c".format(i): 1, 
            "atp_c": 1, 
            "pyr_c": 1})
    
    if i < n_subunits:
        # Make enzyme reactions for enzyme-activator binding
        PYK.make_enzyme_module_reaction(
            id="PYK_R{0:d}0".format(i + 1), 
            name="Automatic",
            subsystem="Glycolysis",
            reversible=True,
            categories="fdp_c activation",
            metabolites_to_add={
                "pyk_R{0:d}_c".format(i): -1, 
                "fdp_c": -1, 
                "pyk_R{0:d}_c".format(i + 1): 1})

        # Make enzyme reactions for enzyme-inhibitor binding
        PYK.make_enzyme_module_reaction(
            id="PYK_T{0:d}".format(i + 1), 
            name="Automatic",
            subsystem="Glycolysis",
            reversible=True,
            categories="atp_c inhibition",
            metabolites_to_add={
                "pyk_T{0:d}_c".format(i): -1, 
                "atp_c": -1, 
                "pyk_T{0:d}_c".format(i + 1): 1})
# Make reaction representing enzyme transition from R to T state
PYK.make_enzyme_module_reaction(
    id="PYK_L",
    name="Automatic",
    subsystem="Glycolysis",
    reversible=True,
    categories="R/T transition",
    metabolites_to_add={
        "pyk_R0_c": -1, 
        "pyk_T0_c": 1})

# Access DictList of EnzymeModuleForms and print
print("All {0} EnzymeModuleReactions ({1} total):\n{2}\n".format(
    PYK.id, len(PYK.enzyme_module_reactions), str([r.id for r in PYK.enzyme_module_reactions])))
# Access categorized dict attribute for EnzymeModuleForms and print
for category, enz_reactions in PYK.enzyme_module_reactions_categorized.items():
    print("{0}: {1}\n".format(
        category, str([r.id for r in enz_reactions])))
# Out:
# All PYK EnzymeModuleReactions (34 total):
# ['PYK_R01', 'PYK_R02', 'PYK_R03', 'PYK_R04', 'PYK_R05', 'PYK_R10', 'PYK_T1', 'PYK_R11', 'PYK_R12', 'PYK_R13', 'PYK_R14', 'PYK_R15', 'PYK_R20', 'PYK_T2', 'PYK_R21', 'PYK_R22', 'PYK_R23', 'PYK_R24', 'PYK_R25', 'PYK_R30', 'PYK_T3', 'PYK_R31', 'PYK_R32', 'PYK_R33', 'PYK_R34', 'PYK_R35', 'PYK_R40', 'PYK_T4', 'PYK_R41', 'PYK_R42', 'PYK_R43', 'PYK_R44', 'PYK_R45', 'PYK_L']
#
# pep_c binding: ['PYK_R01', 'PYK_R03', 'PYK_R11', 'PYK_R13', 'PYK_R21', 'PYK_R23', 'PYK_R31', 'PYK_R33', 'PYK_R41', 'PYK_R43']
#
# adp_c binding: ['PYK_R02', 'PYK_R04', 'PYK_R12', 'PYK_R14', 'PYK_R22', 'PYK_R24', 'PYK_R32', 'PYK_R34', 'PYK_R42', 'PYK_R44']
#
# catalyzation: ['PYK_R05', 'PYK_R15', 'PYK_R25', 'PYK_R35', 'PYK_R45']
#
# fdp_c activation: ['PYK_R10', 'PYK_R20', 'PYK_R30', 'PYK_R40']
#
# atp_c inhibition: ['PYK_T1', 'PYK_T2', 'PYK_T3', 'PYK_T4']
#
# R/T transition: ['PYK_L']

# %% [markdown]
# ### Create and  Unify Rate Parameters
# The next step is to unify rate parameters of binding steps that are not unique, allowing for those parameter values to be defined once and stored in the same place. Therefore, custom rate laws with custom parameters are used to reduce the number of parameters that need to be defined and better represent the module.
#
# The rate law parameters can be unified using the <font color=#4682B4>EnzymeModule</font><font color=#00008B>.unify_rate_parameters</font> class method. This method requires a list of reactions whose rate laws that should be identical, along with a string representation of the new identifier to use on the unified parameters. There is also the optional <font color=#B22222>prefix </font> argument, which if set to True, will ensure the new parameter identifiers are prefixed with the <font color=#4682B4>EnzymeModule</font> identifier. This can be used to help prevent custom parameters from being replaced when multiple models are merged.
#
# #### Allosteric Transitions: Symmetry Model
#
# Once rate parameters are unified, the allosteric regulation of this enzyme must be accounted for. Because this module is to be based on the (Monod-Wyman-Changeux) MWC model for ligand binding and allosteric regulation, the rate laws of the allosteric binding reactions must be adjusted to reflect the symmetry in the module using the number of identical binding sites to help determine the scalars for the parameters.
#
# For this module, PYK is considered a homotetramer, meaning it has four identical subunits \\(\nu = 4\\). Each subunit can be allosterically activated by FDP or inhibited by ATP. The helper functions <font color=#00008B>k2Keq</font>, <font color=#00008B>Keq2k</font>, and <font color=#00008B>strip_time</font> from the <font color=#0000FF>mass.util</font> submodule will be used to help facilitate the rate law changes in this example so that the final rate laws are dependent on the forward rate (kf) and equilibrium (Keq) constants.

# %%
enzyme_prefix = True
abbreviations = ["P", "A", "I", "ACT"]
ligands = [pep_c, adp_c, atp_c, fdp_c]

for met, unified_id in zip(ligands, abbreviations):
    category = {"P": "binding",
                "A": "binding",
                "I": "inhibition",
                "ACT": "activation"}[unified_id]
    reactions = PYK.enzyme_module_reactions_categorized[" ".join((met.id, category))]
    PYK.unify_rate_parameters(reactions, unified_id, rate_type=2, enzyme_prefix=enzyme_prefix)
    # Add the coefficients to make symmetry model rate laws for activation and inhibition 
    if unified_id in ["I", "ACT"]:
        for i, reaction in enumerate(reactions):
            custom_rate = str(strip_time((reaction.rate)))
            custom_rate = custom_rate.replace("kf_", "{0:d}*kf_".format(n_subunits - i))
            custom_rate = custom_rate.replace("kr_", "{0:d}*kr_".format(i + 1))
            PYK.add_custom_rate(reaction, custom_rate)

PYK.unify_rate_parameters(PYK.enzyme_module_reactions_categorized["catalyzation"], "PYK")
# Update rate laws to be in terms of kf and Keq
PYK.custom_rates.update(k2Keq(PYK.custom_rates))

# Display newly made reactions in their categories
for category, enzyme_module_reactions in PYK.enzyme_module_reactions_categorized.items():
    header = "Category: " + category
    print("\n" + header + "\n" + "-" * len(header))
    for reaction in enzyme_module_reactions:
        print(reaction.id + ": " + str(reaction.rate))
# Out:
# Category: pep_c binding
# -----------------------
# PYK_R01: kf_PYK_P*(pep_c(t)*pyk_R0_c(t) - pyk_R0_P_c(t)/Keq_PYK_P)
# PYK_R03: kf_PYK_P*(pep_c(t)*pyk_R0_A_c(t) - pyk_R0_AP_c(t)/Keq_PYK_P)
# PYK_R11: kf_PYK_P*(pep_c(t)*pyk_R1_c(t) - pyk_R1_P_c(t)/Keq_PYK_P)
# PYK_R13: kf_PYK_P*(pep_c(t)*pyk_R1_A_c(t) - pyk_R1_AP_c(t)/Keq_PYK_P)
# PYK_R21: kf_PYK_P*(pep_c(t)*pyk_R2_c(t) - pyk_R2_P_c(t)/Keq_PYK_P)
# PYK_R23: kf_PYK_P*(pep_c(t)*pyk_R2_A_c(t) - pyk_R2_AP_c(t)/Keq_PYK_P)
# PYK_R31: kf_PYK_P*(pep_c(t)*pyk_R3_c(t) - pyk_R3_P_c(t)/Keq_PYK_P)
# PYK_R33: kf_PYK_P*(pep_c(t)*pyk_R3_A_c(t) - pyk_R3_AP_c(t)/Keq_PYK_P)
# PYK_R41: kf_PYK_P*(pep_c(t)*pyk_R4_c(t) - pyk_R4_P_c(t)/Keq_PYK_P)
# PYK_R43: kf_PYK_P*(pep_c(t)*pyk_R4_A_c(t) - pyk_R4_AP_c(t)/Keq_PYK_P)
#
# Category: adp_c binding
# -----------------------
# PYK_R02: kf_PYK_A*(adp_c(t)*pyk_R0_c(t) - pyk_R0_A_c(t)/Keq_PYK_A)
# PYK_R04: kf_PYK_A*(adp_c(t)*pyk_R0_P_c(t) - pyk_R0_AP_c(t)/Keq_PYK_A)
# PYK_R12: kf_PYK_A*(adp_c(t)*pyk_R1_c(t) - pyk_R1_A_c(t)/Keq_PYK_A)
# PYK_R14: kf_PYK_A*(adp_c(t)*pyk_R1_P_c(t) - pyk_R1_AP_c(t)/Keq_PYK_A)
# PYK_R22: kf_PYK_A*(adp_c(t)*pyk_R2_c(t) - pyk_R2_A_c(t)/Keq_PYK_A)
# PYK_R24: kf_PYK_A*(adp_c(t)*pyk_R2_P_c(t) - pyk_R2_AP_c(t)/Keq_PYK_A)
# PYK_R32: kf_PYK_A*(adp_c(t)*pyk_R3_c(t) - pyk_R3_A_c(t)/Keq_PYK_A)
# PYK_R34: kf_PYK_A*(adp_c(t)*pyk_R3_P_c(t) - pyk_R3_AP_c(t)/Keq_PYK_A)
# PYK_R42: kf_PYK_A*(adp_c(t)*pyk_R4_c(t) - pyk_R4_A_c(t)/Keq_PYK_A)
# PYK_R44: kf_PYK_A*(adp_c(t)*pyk_R4_P_c(t) - pyk_R4_AP_c(t)/Keq_PYK_A)
#
# Category: catalyzation
# ----------------------
# PYK_R05: kf_PYK*pyk_R0_AP_c(t)
# PYK_R15: kf_PYK*pyk_R1_AP_c(t)
# PYK_R25: kf_PYK*pyk_R2_AP_c(t)
# PYK_R35: kf_PYK*pyk_R3_AP_c(t)
# PYK_R45: kf_PYK*pyk_R4_AP_c(t)
#
# Category: fdp_c activation
# --------------------------
# PYK_R10: kf_PYK_ACT*(4*fdp_c(t)*pyk_R0_c(t) - pyk_R1_c(t)/Keq_PYK_ACT)
# PYK_R20: kf_PYK_ACT*(3*fdp_c(t)*pyk_R1_c(t) - 2*pyk_R2_c(t)/Keq_PYK_ACT)
# PYK_R30: kf_PYK_ACT*(2*fdp_c(t)*pyk_R2_c(t) - 3*pyk_R3_c(t)/Keq_PYK_ACT)
# PYK_R40: kf_PYK_ACT*(fdp_c(t)*pyk_R3_c(t) - 4*pyk_R4_c(t)/Keq_PYK_ACT)
#
# Category: atp_c inhibition
# --------------------------
# PYK_T1: kf_PYK_I*(4*atp_c(t)*pyk_T0_c(t) - pyk_T1_c(t)/Keq_PYK_I)
# PYK_T2: kf_PYK_I*(3*atp_c(t)*pyk_T1_c(t) - 2*pyk_T2_c(t)/Keq_PYK_I)
# PYK_T3: kf_PYK_I*(2*atp_c(t)*pyk_T2_c(t) - 3*pyk_T3_c(t)/Keq_PYK_I)
# PYK_T4: kf_PYK_I*(atp_c(t)*pyk_T3_c(t) - 4*pyk_T4_c(t)/Keq_PYK_I)
#
# Category: R/T transition
# ------------------------
# PYK_L: kf_PYK_L*(pyk_R0_c(t) - pyk_T0_c(t)/Keq_PYK_L)

# %% [markdown]
# ## The Steady State
# ### Solve steady state concentrations symbolically
# To determine the steady state of the enzyme, a dictionary of the ordinary differential equations as symbolic expressions for each of the <font color=#4682B4>EnzymeModuleForms</font>.
#
# For handling of all symbolic expressions in <b>masspy</b>, the <b>sympy</b> package is used.

# %%
ode_dict = {
    sym.Symbol(enzyme_module_form.id): sym.Eq(strip_time(enzyme_module_form.ode))
    for enzyme_module_form in PYK.enzyme_module_forms}

rank = matrix_rank(PYK.S[6:])
print("Rank Deficiency: {0}".format(len(ode_dict) - rank))
# Out:
# Rank Deficiency: 1

# %% [markdown]
# In order to solve the system of ODEs for the steady state concentrations, an additional equation is required due to the rank deficiency of the stoichiometric matrix. Therefore, the equation for the steady state flux through the enzyme, which will be referred to as the "enzyme net flux equation", must be defined.
#
# To define the enzyme net flux equation, the <font color=#4682B4>EnzymeModule</font><font color=#00008B>.make_enzyme_netflux_equation</font> class method can be used.
#
# * This equation is made by providing a reaction, or a list of reactions to add together.
# * Passing a bool to <font color=#B22222>use_rates</font> argument determines whether a symbolic equation is a summation of the flux symbols returned by <font color=#4682B4>EnzymeModuleReaction</font><font color=#1E90FF>.flux_symbol</font>, or a summation of the rates laws for those reactions.
# * The <font color=#B22222>update_enzyme</font> argument determines whether the new rate equation is set in the <font color=#1E90FF>enzyme_net_flux_equation</font> attribute.
#
# The flux through the enzyme typically corresponds to the sum of the fluxes through the catalytic reaction steps.
# Because the catalyzation reactions were assigned to the "catalyzation" cateogry, they can be accessed through the <font color=#1E90FF>enzyme_module_reactions_categorized</font> attribute to create the equation for \\(v_{\mathrm{PYK}}\\).

# %%
PYK.make_enzyme_net_flux_equation(PYK.enzyme_module_reactions_categorized["catalyzation"], 
                                  use_rates=True, update_enzyme=True)
sym.pprint(PYK.enzyme_net_flux_equation)
# Out:
# v_PYK = kf_PYK⋅(pyk_R0_AP_c(t) + pyk_R1_AP_c(t) + pyk_R2_AP_c(t) + pyk_R3_AP_c
# (t) + pyk_R4_AP_c(t))

# %% [markdown]
# The next step is to identify equations for the unknown concentrations in each reaction. These equations will need to be solved with a dependent variable before accounting for the enzyme net flux equation. The completely free form of the enzyme with no bound species will be treated as the dependent variable.
#
# To verify that all equations are in terms of the rate parameters, ligand concentrations, and the dependent variable, the solutions can be iterated through using the atoms method to identify the equation arguments.
#
# There should be no <font color=#4682B4>EnzymeModuleForm</font> identifiers with the exception of the dependent variable.

# %%
# Get enzyme forms
enzyme_module_forms = PYK.enzyme_module_forms.copy()
# Reverse list for increased performance (due to symmetry assumption)
# by solving for the most activated/inhibitors bound first.
enzyme_module_forms.reverse()

enzyme_solutions = {}
for enzyme_module_form in enzyme_module_forms:
    # Skip dependent variable
    if "pyk_R0_c" == str(enzyme_module_form):
        continue
    enzyme_module_form = sym.Symbol(enzyme_module_form.id)
    # Susbtitute in previous solutions and solve for the enzyme module form, 
    equation = ode_dict[enzyme_module_form]
    sol = sym.solveset(equation.subs(enzyme_solutions), enzyme_module_form)
    enzyme_solutions[enzyme_module_form] = list(sol)[0]
    # Update the dictionary of solutions with the solutions
    enzyme_solutions.update({enzyme_module_form: sol.subs(enzyme_solutions) 
                             for enzyme_module_form, sol in enzyme_solutions.items()})
args = set()
for sol in enzyme_solutions.values():
    args.update(sol.atoms(sym.Symbol))
print(args)
# Out:
# {atp_c, Keq_PYK_P, fdp_c, Keq_PYK_ACT, adp_c, kf_PYK_A, Keq_PYK_I, kf_PYK, kf_PYK_P, pyk_R0_c, pep_c, Keq_PYK_A, Keq_PYK_L}

# %% [markdown]
# The enzyme net flux equation can then be utilized as the last equation required to solve for the final unknown concentration variable in terms of the rate and equilibrium constants, allowing for all of the concentration variables to be defined in terms of the parameters and ligand concentrations. Once the unknown variable has been solved for, the solution can be substituted back into the other equations. Because <b>sympy</b><font color=#8B008B>.solveset</font> function expects the input equations to be equal to 0, the <font color=#4682B4>EnzymeModule</font><font color=#00008B>.enzyme_net_flux_error</font> method with the <font color=#B22222>use_values</font>  argument set to False to get the appropriate expression.

# %%
enzyme_net_flux_equation = strip_time(PYK.enzyme_net_flux_error(False))
print("Enzyme Net Flux Equation\n" + "-"*24)
sym.pprint(enzyme_net_flux_equation)

# Solve for last unknown concentration symbolically
sol = sym.solveset(enzyme_net_flux_equation.subs(enzyme_solutions), "pyk_R0_c")

# Update solution dictionary with the new solution
enzyme_solutions[sym.Symbol("pyk_R0_c")] = list(sol)[0]

# Update solutions with free variable solutions
enzyme_solutions = {
    enzyme_module_form: sym.simplify(solution.subs(enzyme_solutions))
    for enzyme_module_form, solution in enzyme_solutions.items()}

args = set()
for sol in enzyme_solutions.values():
    args.update(sol.atoms(sym.Symbol))
print("\n", args)
# Out:
# Enzyme Net Flux Equation
# ------------------------
# -kf_PYK⋅(pyk_R0_AP_c + pyk_R1_AP_c + pyk_R2_AP_c + pyk_R3_AP_c + pyk_R4_AP_c)
# + v_PYK
#  {atp_c, Keq_PYK_P, fdp_c, Keq_PYK_ACT, adp_c, kf_PYK_A, v_PYK, Keq_PYK_I, kf_PYK, kf_PYK_P, pep_c, Keq_PYK_A, Keq_PYK_L}

# %% [markdown]
# #### Numerical Values
# At this point, numerical values are defined for the dissociation constants and the concentrations of the substrates, cofactors, activators, and inhibitors. Providing these numerical values will speed up the subsequent calculations.
#
# To do this, experimental data is used to define the dissociations constants for the different binding steps under the QEA assumption. The concentrations of the non-enzyme species are taken from the glycolysis model.
#
# Experimental data gives the following for the dissociation constants:
#
# $$\\K_i=3.39 mM,\ K_a=0.005 mM,\ K_A=0.474 mM,\ K_P=0.225 mM,\ $$ and an allosteric constant of \\(K_L = 19\\).

# %%
numerical_values = {}

# Get ligand IDs and parameter IDs
ligand_ids = sorted([str(ligand) for ligand in PYK.enzyme_module_ligands])
parameter_ids = ["_".join((PYK.id, abbrev)) for abbrev in abbreviations + ["L"]]
print("Ligand IDs: " + str(ligand_ids))
print("Parameter IDs: " + str(parameter_ids))

# Load the glycolysis model to extract steady state values
glycolysis = json.load_json_model(path.realpath(path.join("models", "Glycolysis.json")))

# Get the steady state flux value and add to numerical values
PYK.enzyme_net_flux = glycolysis.reactions.get_by_id(PYK.id).steady_state_flux
numerical_values.update({PYK.enzyme_flux_symbol: PYK.enzyme_net_flux})

# Get the steady state concentration values and add to numerical values
initial_conditions = {
    str(ligand): glycolysis.initial_conditions[glycolysis.metabolites.get_by_id(ligand)]
    for ligand in ligand_ids}
numerical_values.update(initial_conditions)
# Define parameter values and add to numerical values
# Because of the QEA, invert dissociation constants for Keq
parameter_values = {
    "Keq_" + parameter_id: value 
    for parameter_id, value in zip(parameter_ids, [1/0.225, 1/0.474, 1/3.39, 1/0.005, 19])}
numerical_values.update(parameter_values)

# Display numerical values
print("\nNumerical Values\n----------------")
for k, v in numerical_values.items():
    print("{0} = {1}".format(k, v))
# Out:
# Ligand IDs: ['adp_c', 'atp_c', 'fdp_c', 'h_c', 'pep_c', 'pyr_c']
# Parameter IDs: ['PYK_P', 'PYK_A', 'PYK_I', 'PYK_ACT', 'PYK_L']
#
# Numerical Values
# ----------------
# v_PYK = 2.24
# adp_c = 0.29
# atp_c = 1.6
# fdp_c = 0.0146
# h_c = 8.99757e-05
# pep_c = 0.017
# pyr_c = 0.060301
# Keq_PYK_P = 4.444444444444445
# Keq_PYK_A = 2.109704641350211
# Keq_PYK_I = 0.2949852507374631
# Keq_PYK_ACT = 200.0
# Keq_PYK_L = 19

# %% [markdown]
# The last part of this step is to simplify the solutions for the enzyme forms and, as a QA check, ensure that only rate constants are the only symbolic arguments in the solutions.

# %%
# Substitute values into equations
enzyme_solutions = {
    enzyme_module_form: sym.simplify(solution.subs(numerical_values))
    for enzyme_module_form, solution in enzyme_solutions.items()}

args = set()
for sol in enzyme_solutions.values():
    args.update(sol.atoms(sym.Symbol))
print(args)
# Out:
# {kf_PYK_A, kf_PYK_P, kf_PYK}

# %% [markdown]
# ### Determine rate constants
# #### Total Enzyme Concentration and $r_{T}$
# After solving for the enzyme forms, the next step is to define equations for the total enzyme concentration and for the fraction of the enzyme in the T state. These two equations can be used as constraints for determining the rate parameters. To view the equation for the total enzyme concentration, we can use the <font color=#4682B4>EnzymeModule</font><font color=1E90FF>.enzyme_concentration_total_equation</font> property.

# %%
sym.pprint(PYK.enzyme_concentration_total_equation)
# Out:
# PYK_Total = pyk_R0_AP_c(t) + pyk_R0_A_c(t) + pyk_R0_P_c(t) + pyk_R0_c(t) + pyk
# _R1_AP_c(t) + pyk_R1_A_c(t) + pyk_R1_P_c(t) + pyk_R1_c(t) + pyk_R2_AP_c(t) + p
# yk_R2_A_c(t) + pyk_R2_P_c(t) + pyk_R2_c(t) + pyk_R3_AP_c(t) + pyk_R3_A_c(t) +
# pyk_R3_P_c(t) + pyk_R3_c(t) + pyk_R4_AP_c(t) + pyk_R4_A_c(t) + pyk_R4_P_c(t) +
#  pyk_R4_c(t) + pyk_T0_c(t) + pyk_T1_c(t) + pyk_T2_c(t) + pyk_T3_c(t) + pyk_T4_
# c(t)

# %% [markdown]
# The total concentration of PYK is 69 nM (=0.000069 mM). The <font color=#4682B4>EnzymeModule</font><font color=1E90FF>.enzyme_concentration_total</font> atrribute can be used to set and store this concentration.

# %%
PYK.enzyme_concentration_total = 69e-6
print(PYK.enzyme_concentration_total)
# Out:
# 6.9e-05

# %% [markdown]
# To determine the rate constants, an optimization problem where the objective function is to minimize the error between the measured and calculated total enzyme concentrations. To create the objective function, the <font color=#4682B4>EnzymeModule</font><font color=#00008B>.enzyme_concentration_total_error</font> method with the <font color=#B22222>use_values</font> argument set as False to get the symbolic expression of the constraint.

# %%
enzyme_total_constraint = abs(strip_time(PYK.enzyme_concentration_total_error(use_values=False)))
sym.pprint(enzyme_total_constraint)
# Out:
# │-PYK_Total + pyk_R0_AP_c + pyk_R0_A_c + pyk_R0_P_c + pyk_R0_c + pyk_R1_AP_c +
#  pyk_R1_A_c + pyk_R1_P_c + pyk_R1_c + pyk_R2_AP_c + pyk_R2_A_c + pyk_R2_P_c +
# pyk_R2_c + pyk_R3_AP_c + pyk_R3_A_c + pyk_R3_P_c + pyk_R3_c + pyk_R4_AP_c + py
# k_R4_A_c + pyk_R4_P_c + pyk_R4_c + pyk_T0_c + pyk_T1_c + pyk_T2_c + pyk_T3_c +
#  pyk_T4_c│

# %% [markdown]
# Substitute the solutions for the enzyme forms to get an equation for the error in the enzyme total concentration in terms of the rate constants.

# %%
# Substitute value for enzyme concentration total
enzyme_total_constraint = enzyme_total_constraint.subs({PYK.enzyme_total_symbol: PYK.enzyme_concentration_total})
# Substitute solutions into constraint and simplify
enzyme_total_constraint = sym.simplify(enzyme_total_constraint.subs(enzyme_solutions))

# %% [markdown]
# To create the objective function in a format suitable for the minimization method from the <b>scipy</b><font color=#800080>.optimize</font> submodule, the <b>sympy</b><font color=#8B008B>.lambdify</font> function can be used to convert the symbolic expression into a lambda function with the rate constants as the arguments. This lambda function can then be used to generate the objective function for the <font color=#800080>optimize</font><font color=#8B008B>.minimize</font> method.

# %%
# Create a sorted tuple of the arguments to ensure the input format does not change
args = tuple(sorted([str(arg) for arg in list(args)]))
# Create the objective function as a lambda function
objective_function = lambda x: sym.lambdify(args, enzyme_total_constraint)(*x)

# %% [markdown]
# Another constraint can be set on the amount of inhibited enzyme in the steady state of the system using the T fraction (denoted as \\(r_{T}\\)). This fraction is simply the amount of inhibited enzyme over the total amount of enzyme. Assume 15-25% of PYK is in inhibited form for this constraint.
#
# To make the fraction as a symbolic expression, we can use the <font color=#4682B4>EnzymeModule</font><font color=#00008B>.make_enzyme_fraction</font> method. This method is designed to assist in making fractions and ratios by passing to the function:
# 1. A string to the <font color=#B22222>categorized_attr</font> argument identifying which categorized dict attribute (either "forms" for the <font color=#4682B4>EnzymeModule</font><font color=1E90FF>.enzyme_module_forms_categorized</font> or "reactions" for the <font color=#4682B4>EnzymeModule</font><font color=1E90FF>.enzyme_module_reactions_categorized</font>).
# 2. A string for the <font color=#B22222>top</font> argument and a string for the <font color=#B22222>bottom</font> argument identifying the categories to sum and use in the numerator and the denominator, respectively.
# 3. A bool to the <font color=#B22222>use_values</font> argument indicating whether to substitute numerical values into the expression to return a float or to keep the ratio as a sympy expression.
#
# __Note:__ The string "Equation" can be passed to either the <font color=#B22222>top</font> or <font color=#B22222>bottom</font> arguments to utilize the equation stored either in <font color=1E90FF>enzyme_concentration_total_equation</font> (for <font color=#B22222>categorized_attr</font>="forms"), or   <font color=1E90FF>enzyme_net_flux_equation</font> (for <font color=#B22222>categorized_attr</font>="reactions").

# %%
# Set the values for the constraint bounds
r_T_lb, r_T_ub = (0.15, 0.25)
# Make a symbolic expression for enzyme fraction.
r_T_expr = PYK.make_enzyme_fraction(categorized_attr="forms", top="Tense", bottom="Equation", use_values=False)
# Substitute solutions into the expression to make
# solely dependent on the rate constants
r_T_expr = sym.simplify(strip_time(r_T_expr).subs(enzyme_solutions))

# Make lambda functions for the T fraction constraint
r_T_lb_constraint = lambda x: sym.lambdify(args, r_T_expr - r_T_lb)(*x)
r_T_ub_constraint = lambda x: sym.lambdify(args, r_T_ub - r_T_expr)(*x)

# %% [markdown]
# Lastly, we place lower and upper bounds on the rate constants to ensure that the values are non-negative and are within physiological limits, and then we solve the optmization problem. Once the optimization has finished, we check whether it was successful, and if so, what the optimality and errors are associated with this particular solution instance.

# %%
print("Ordered Args: {0}\n".format(str(args)))
# Set arguments for minimization 
initial_guess = [1e6, 1e7, 1e7]
kf_bounds = ((1e3, 1e9), (1e3, 1e9), (1e3, 1e9))
constraints = (
    {"type": "ineq", "fun": r_T_ub_constraint},
    {"type": "ineq", "fun": r_T_lb_constraint})

# Find a feasible solution
sol = optimize.minimize(
    objective_function, x0=initial_guess, method="trust-constr",
    bounds=kf_bounds, constraints=constraints,
    options={"gtol": 1e-12, "xtol": 1e-12, "maxiter": 1e4, "disp": True})

# Check whether optimzation was successful
print("\nOptimization Success: {0}".format(sol.success))
if sol.success:
    # Update the paramter values dictionary with the feasible solution
    parameter_values.update(dict(zip(args, [round(x) for x in sol.x])))
    print("Optimization Optimality: {0:.4e}".format(sol.optimality))
    print("Parameter Solutions: {:}".format(str({arg: parameter_values[arg] for arg in args})))
    # Plug solutions back into constraints for validation
    print("Optimization Error: {0:.4e}".format(enzyme_total_constraint.subs(parameter_values)))
    print("Enzyme T-fraction: {:.4f}".format(r_T_expr.subs(parameter_values)))
# Out:
# Ordered Args: ('kf_PYK', 'kf_PYK_A', 'kf_PYK_P')
# `xtol` termination condition is satisfied.
# Number of iterations: 121, function evaluations: 360, CG iterations: 174, optimality: 9.06e-12, constraint violation: 0.00e+00, execution time: 1.1e+01 s.
#
# Optimization Success: True
# Optimization Optimality: 9.0555e-12
# Parameter Solutions: {'kf_PYK': 2207479.0, 'kf_PYK_A': 10091263.0, 'kf_PYK_P': 10090163.0}
# Optimization Error: 5.1714e-13
# Enzyme T-fraction: 0.1821

# %% [markdown]
# With a successful optimization, the module is updated with the parameter values.  The inhibition and activation reactions are set to have a high forward rate constant and the allosteric transition even higher, limiting the amount of unbound enzyme and ensuring that the dynamics are determined by the dissociation and allosteric constants.
#
# __Note:__ This assumption for the rate constants can be made because none of the enzyme concentrations are dependendent on the activation, inhibition, and allosteric rate constants.

# %%
# Add the activation, inhibition, and allosteric rate constants
for abbrev, value in zip(["I", "ACT", "L"], [1e6, 1e6, 1e6**2]):
    to_join = ("kf", PYK.id, abbrev) if enzyme_prefix else ("kf", abbrev)
    param = "_".join(to_join)
    parameter_values.update({param: value})
# Display values
for k, v in parameter_values.items():
    print("{0} = {1}".format(k, v))
# Out:
# Keq_PYK_P = 4.444444444444445
# Keq_PYK_A = 2.109704641350211
# Keq_PYK_I = 0.2949852507374631
# Keq_PYK_ACT = 200.0
# Keq_PYK_L = 19
# kf_PYK = 2207479.0
# kf_PYK_A = 10091263.0
# kf_PYK_P = 10090163.0
# kf_PYK_I = 1000000.0
# kf_PYK_ACT = 1000000.0
# kf_PYK_L = 1000000000000.0

# %% [markdown]
# ### Solve steady state concentrations numerically
# Once the rate constants have been defined, the steady state concentrations of the enzyme can be determined.

# %%
# Substitute values into equations
initial_conditions.update({
    str(enzyme_module_form): round(float(sym.simplify(solution.subs(parameter_values))), 12)
    for enzyme_module_form, solution in enzyme_solutions.items()})

for header, dictlist in zip(["Ligand", "\nEnzyme"], [PYK.enzyme_module_ligands, PYK.enzyme_module_forms]):
    header += " Concentrations"
    print("\n".join([header, "-" * len(header)]))
    for species in dictlist:
        ic = initial_conditions[species.id]
        print("{0} = {1}".format(species.id, ic))
# Out:
# Ligand Concentrations
# ---------------------
# pep_c = 0.017
# adp_c = 0.29
# fdp_c = 0.0146
# atp_c = 1.6
# pyr_c = 0.060301
# h_c = 8.99757e-05
#
# Enzyme Concentrations
# ----------------------
# pyk_R0_c = 1.40899e-07
# pyk_R0_A_c = 8.5189e-08
# pyk_R0_P_c = 8.606e-09
# pyk_R0_AP_c = 4.297e-09
# pyk_T0_c = 2.677077e-06
# pyk_R1_c = 1.645698e-06
# pyk_R1_A_c = 9.95003e-07
# pyk_R1_P_c = 1.00521e-07
# pyk_R1_AP_c = 5.0194e-08
# pyk_T1_c = 5.054068e-06
# pyk_R2_c = 7.208156e-06
# pyk_R2_A_c = 4.358114e-06
# pyk_R2_P_c = 4.4028e-07
# pyk_R2_AP_c = 2.19849e-07
# pyk_T2_c = 3.578101e-06
# pyk_R3_c = 1.4031877e-05
# pyk_R3_A_c = 8.483795e-06
# pyk_R3_P_c = 8.57079e-07
# pyk_R3_AP_c = 4.27972e-07
# pyk_T3_c = 1.125853e-06
# pyk_R4_c = 1.024327e-05
# pyk_R4_A_c = 6.19317e-06
# pyk_R4_P_c = 6.25668e-07
# pyk_R4_AP_c = 3.1242e-07
# pyk_T4_c = 1.32844e-07

# %% [markdown]
# #### Set Initial Conditions and Parameters
# Once the steady state concentrations have been determined, the initial conditions and parameters are added to the module. All custom parameter are added to the custom_parameter attribute. The allosteric transition uses the standard parameter identifiers (returned by <font color=1E90FF>kf_str</font> and <font color=1E90FF>Keq_str</font> properties of the <font color=#4682B4>EnzymeModuleReaction</font>), so they are popped out of the custom_parameters and set through their respective attribute setter methods.

# %%
# Set initial conditions
for met, concentration in initial_conditions.items():
    PYK.metabolites.get_by_id(str(met)).ic = concentration

# Add the custom parameters and values for kf and Keq to model
PYK.custom_parameters.update(parameter_values)
# PYK_L uses standard reaction parameters and not custom parameters
PYK_L = PYK.enzyme_module_reactions.PYK_L
PYK_L.kf = PYK.custom_parameters.pop(PYK_L.kf_str)
PYK_L.Keq = PYK.custom_parameters[PYK_L.Keq_str]

# %% [markdown]
# #### Ordering of internal species and reactions
#
# Sometimes, it is also desirable to reorder the metabolite and reaction objects inside the model to follow the physiology. To reorder the internal species, one can use <font color=#008000>cobra</font><font color=#556B2F>.DictLists</font> and the <font color=#556B2F>DictList</font><font color=#006400>.get_by_any</font> with the list of metabolite identifiers in the desirable order. To ensure all metabolites and reactions are still present and not forgotten in the model, a small QA check is also performed.

# %%
new_metabolite_order = [
    'pep_c', 'pyr_c', 'fdp_c', 'adp_c', 'atp_c',
    'pyk_R0_c', 'pyk_R0_P_c', 'pyk_R0_A_c', 'pyk_R0_AP_c', 
    'pyk_R1_c', 'pyk_R1_P_c', 'pyk_R1_A_c', 'pyk_R1_AP_c',
    'pyk_R2_c', 'pyk_R2_P_c', 'pyk_R2_A_c', 'pyk_R2_AP_c',
    'pyk_R3_c', 'pyk_R3_P_c', 'pyk_R3_A_c', 'pyk_R3_AP_c',
    'pyk_R4_c', 'pyk_R4_P_c', 'pyk_R4_A_c', 'pyk_R4_AP_c',
    'pyk_T0_c', 'pyk_T1_c', 'pyk_T2_c', 'pyk_T3_c', 'pyk_T4_c']

if len(PYK.metabolites) == len(new_metabolite_order):
    PYK.metabolites = DictList(
        PYK.metabolites.get_by_any(new_metabolite_order))
    
new_reaction_order = [
    "PYK_R01", "PYK_R02", "PYK_R03", "PYK_R04", "PYK_R05", "PYK_R10",
    "PYK_R11", "PYK_R12", "PYK_R13", "PYK_R14", "PYK_R15", "PYK_R20",
    "PYK_R21", "PYK_R22", "PYK_R23", "PYK_R24", "PYK_R25", "PYK_R30", 
    "PYK_R31", "PYK_R32", "PYK_R33", "PYK_R34", "PYK_R35", "PYK_R40", 
    "PYK_R41", "PYK_R42", "PYK_R43", "PYK_R44", "PYK_R45", "PYK_L",
    "PYK_T1", "PYK_T2", "PYK_T3", "PYK_T4"]

if len(PYK.reactions) == len(new_reaction_order):
    PYK.reactions = DictList(
        PYK.reactions.get_by_any(new_reaction_order))
    
PYK.update_S(matrix_type="DataFrame", dtype=int)
# Out:
#              PYK_R01  PYK_R02  PYK_R03  PYK_R04  PYK_R05  PYK_R10  PYK_R11  \
# pep_c             -1        0       -1        0        0        0       -1
# adp_c              0       -1        0       -1        0        0        0
# fdp_c              0        0        0        0        0       -1        0
# atp_c              0        0        0        0        1        0        0
# pyr_c              0        0        0        0        1        0        0
# h_c                0        0        0        0       -1        0        0
# pyk_R0_c          -1       -1        0        0        1       -1        0
# pyk_R0_A_c         0        1       -1        0        0        0        0
# pyk_R0_P_c         1        0        0       -1        0        0        0
# pyk_R0_AP_c        0        0        1        1       -1        0        0
# pyk_T0_c           0        0        0        0        0        0        0
# pyk_R1_c           0        0        0        0        0        1       -1
# pyk_R1_A_c         0        0        0        0        0        0        0
# pyk_R1_P_c         0        0        0        0        0        0        1
# pyk_R1_AP_c        0        0        0        0        0        0        0
# pyk_T1_c           0        0        0        0        0        0        0
# pyk_R2_c           0        0        0        0        0        0        0
# pyk_R2_A_c         0        0        0        0        0        0        0
# pyk_R2_P_c         0        0        0        0        0        0        0
# pyk_R2_AP_c        0        0        0        0        0        0        0
# pyk_T2_c           0        0        0        0        0        0        0
# pyk_R3_c           0        0        0        0        0        0        0
# pyk_R3_A_c         0        0        0        0        0        0        0
# pyk_R3_P_c         0        0        0        0        0        0        0
# pyk_R3_AP_c        0        0        0        0        0        0        0
# pyk_T3_c           0        0        0        0        0        0        0
# pyk_R4_c           0        0        0        0        0        0        0
# pyk_R4_A_c         0        0        0        0        0        0        0
# pyk_R4_P_c         0        0        0        0        0        0        0
# pyk_R4_AP_c        0        0        0        0        0        0        0
# pyk_T4_c           0        0        0        0        0        0        0
#
#              PYK_R12  PYK_R13  PYK_R14   ...    PYK_R41  PYK_R42  PYK_R43  \
# pep_c              0       -1        0   ...         -1        0       -1
# adp_c             -1        0       -1   ...          0       -1        0
# fdp_c              0        0        0   ...          0        0        0
# atp_c              0        0        0   ...          0        0        0
# pyr_c              0        0        0   ...          0        0        0
# h_c                0        0        0   ...          0        0        0
# pyk_R0_c           0        0        0   ...          0        0        0
# pyk_R0_A_c         0        0        0   ...          0        0        0
# pyk_R0_P_c         0        0        0   ...          0        0        0
# pyk_R0_AP_c        0        0        0   ...          0        0        0
# pyk_T0_c           0        0        0   ...          0        0        0
# pyk_R1_c          -1        0        0   ...          0        0        0
# pyk_R1_A_c         1       -1        0   ...          0        0        0
# pyk_R1_P_c         0        0       -1   ...          0        0        0
# pyk_R1_AP_c        0        1        1   ...          0        0        0
# pyk_T1_c           0        0        0   ...          0        0        0
# pyk_R2_c           0        0        0   ...          0        0        0
# pyk_R2_A_c         0        0        0   ...          0        0        0
# pyk_R2_P_c         0        0        0   ...          0        0        0
# pyk_R2_AP_c        0        0        0   ...          0        0        0
# pyk_T2_c           0        0        0   ...          0        0        0
# pyk_R3_c           0        0        0   ...          0        0        0
# pyk_R3_A_c         0        0        0   ...          0        0        0
# pyk_R3_P_c         0        0        0   ...          0        0        0
# pyk_R3_AP_c        0        0        0   ...          0        0        0
# pyk_T3_c           0        0        0   ...          0        0        0
# pyk_R4_c           0        0        0   ...         -1       -1        0
# pyk_R4_A_c         0        0        0   ...          0        1       -1
# pyk_R4_P_c         0        0        0   ...          1        0        0
# pyk_R4_AP_c        0        0        0   ...          0        0        1
# pyk_T4_c           0        0        0   ...          0        0        0
#
#              PYK_R44  PYK_R45  PYK_L  PYK_T1  PYK_T2  PYK_T3  PYK_T4
# pep_c              0        0      0       0       0       0       0
# adp_c             -1        0      0       0       0       0       0
# fdp_c              0        0      0       0       0       0       0
# atp_c              0        1      0      -1      -1      -1      -1
# pyr_c              0        1      0       0       0       0       0
# h_c                0       -1      0       0       0       0       0
# pyk_R0_c           0        0     -1       0       0       0       0
# pyk_R0_A_c         0        0      0       0       0       0       0
# pyk_R0_P_c         0        0      0       0       0       0       0
# pyk_R0_AP_c        0        0      0       0       0       0       0
# pyk_T0_c           0        0      1      -1       0       0       0
# pyk_R1_c           0        0      0       0       0       0       0
# pyk_R1_A_c         0        0      0       0       0       0       0
# pyk_R1_P_c         0        0      0       0       0       0       0
# pyk_R1_AP_c        0        0      0       0       0       0       0
# pyk_T1_c           0        0      0       1      -1       0       0
# pyk_R2_c           0        0      0       0       0       0       0
# pyk_R2_A_c         0        0      0       0       0       0       0
# pyk_R2_P_c         0        0      0       0       0       0       0
# pyk_R2_AP_c        0        0      0       0       0       0       0
# pyk_T2_c           0        0      0       0       1      -1       0
# pyk_R3_c           0        0      0       0       0       0       0
# pyk_R3_A_c         0        0      0       0       0       0       0
# pyk_R3_P_c         0        0      0       0       0       0       0
# pyk_R3_AP_c        0        0      0       0       0       0       0
# pyk_T3_c           0        0      0       0       0       1      -1
# pyk_R4_c           0        1      0       0       0       0       0
# pyk_R4_A_c         0        0      0       0       0       0       0
# pyk_R4_P_c        -1        0      0       0       0       0       0
# pyk_R4_AP_c        1       -1      0       0       0       0       0
# pyk_T4_c           0        0      0       0       0       0       1
#
# [31 rows x 34 columns]

# %% [markdown]
# ## Module Validation
# ### QC/QA model
# Before saving the module, it is important to ensure that the module is elementally balanced, and that the module can be integrated into a larger network for simulation. Therefore, the <font color=#00008B>qcqa_model</font> function from <font color=#0000FF>mass.util.qcqa</font></td> is used to provide a report on the module quality and and indicate whether simulation is possible and if not, what parameters and/or initial conditions are missing.

# %%
qcqa_model(PYK, parameters=True, concentrations=True, 
           fluxes=False, superfluous=True, elemental=True)
# Out:
# ╒═══════════════════════════════╕
# │ MODEL ID: PYK                 │
# │ SIMULATABLE: True;            │
# │ NUMERICAL CONSISTENCY: True   │
# ╞═══════════════════════════════╡
# ╘═══════════════════════════════╛

# %% [markdown]
# ### Constraint Satisfaction and Error Values
# Another QA check we perform is to substitute the steady state numerical values back into the constraints used in determining the rate constants in order to ensure that the constraints remain satisified, and that errors are small.

# %%
t_fraction = PYK.make_enzyme_fraction("forms", top="Tense", bottom="Equation", use_values=True)
print("Enzyme T-fraction: {:.4f}".format(t_fraction))
print("Constraints Satisfied: {0}\n".format(
    r_T_lb <= t_fraction and t_fraction <= r_T_ub))

print("Concentration Absolute Error: {0:.4e}".format(abs(PYK.enzyme_concentration_total_error(use_values=True))))
print("Flux Absolute Error: {0:.4e}".format(abs(PYK.enzyme_net_flux_error(use_values=True))))
# Out:
# Enzyme T-fraction: 0.1821
# Constraints Satisfied: True
#
# Concentration Absolute Error: 6.3792e-21
# Flux Absolute Error: 4.1937e-07

# %% [markdown]
# ### Add Enzyme to MassModel
# In order to determine whether the module can be successfully integrated into a model, another model can be loaded, merged with the module, and simulated. To validate this module, it will be merged with a glycolysis model.
#
# To integrate the <font color=#4682B4>EnzymeModule</font> into the <font color=#4682B4>MassModel</font>, the reaction that the EnzymeModule will be replacing is first removed. The <font color=#4682B4>MassModel</font><font color=#00008B>.merge</font> method can then be utilized to add the <font color=#4682B4>EnzymeModule</font> to the <font color=#4682B4>MassModel</font>.
#
# When merging an <font color=#4682B4>EnzymeModule</font> and a <font color=#4682B4>MassModel</font>, the <font color=#4682B4>EnzymeModule</font> should always be merged into the <font color=#4682B4>MassModel</font>.

# %%
# Load and merge glycolysis and hemoglobin models
glycolysis = json.load_json_model(path.realpath(path.join("models", "Glycolysis.json")))
# Remove the PYK MassReaction, then merge the EnzymeModule into the MassModel
glycolysis.remove_reactions(glycolysis.reactions.get_by_id("PYK"))
glycolysis_PYK = glycolysis.merge(PYK)
glycolysis_PYK
# Out:
# <MassModel Glycolysis_PYK at 0x1280a7358>

# %% [markdown]
# Using <font color=#4682B4>MassModel</font><font color=#00008B>.merge</font> class method enables the <font color=#4682B4>EnzymeModule</font> and <font color=#4682B4>MassModel</font> to be merged like as if they were both <font color=#4682B4>MassModel</font> objects. However, all attributes specific to the <font color=#4682B4>EnzymeModule</font> (e.g the categorized dictionary attributes) are condensed into a speciailzed container called an <font color=#4682B4>EnzymeModuleDict</font>.
#
# The EnzymeModuleDict behaves like an ordered dictionary, but is unique in that its contents can be accessed as if they were attributes. These attributes can be viewed using <font color=#4682B4>EnzymeModuleDict</font>.<font color=#00008B>.keys</font> method.
#
# All <font color=#4682B4>EnzymeModuleDicts</font> associated with a MassModel can be accessed via <font color=#4682B4>MassModel</font><font color=1E90FF>.enzyme_modules</font> attribute.

# %%
print(str(glycolysis_PYK.enzyme_modules) + "\n")
print("Attribute Accessors:\n-------------------\n" + "\n".join(list(
    glycolysis_PYK.enzyme_modules.PYK.keys())) + "\n")
glycolysis_PYK.enzyme_modules.PYK
# Out:
# [<EnzymeModuleDict PYK at 0x127cbb158>]
#
# Attribute Accessors:
# -------------------
# id
# name
# subsystem
# enzyme_module_ligands
# enzyme_module_forms
# enzyme_module_reactions
# enzyme_module_ligands_categorized
# enzyme_module_forms_categorized
# enzyme_module_reactions_categorized
# enzyme_concentration_total
# enzyme_net_flux
# enzyme_net_flux_equation
# description
# S
# model
# <EnzymeModuleDict PYK at 0x127cbb158>

# %% [markdown]
# ### Validate Steady State
#
# To find the steady state of the model, the <font color=#4682B4>Simulation</font><font color=#00008B>.find_steady_state_model</font> method can used, and the
# <font color=#4682B4>Simulation</font><font color=#00008B>.update_values</font> method will update the values in the <font color=#4682B4>Simulation</font> with the steady state values.
# To validate the steady state of the model, concentration and flux solutions can be plotted using the <font color=#00008B>plot_simulation</font> function from <font color=#0000FF>mass.core.visualization</font></td>. Alternatively, the <font color=#4682B4>MassSolution</font><font color=#1E90FF>.preview_time_profile</font> property can be used to quickly generate a time profile for the results

# %%
# Setup simulation object, ensure model is at steady state
sim = Simulation(glycolysis_PYK)
options={'method': 'LSODA', 'atol': 1e-15}
sim.find_steady_state_model(model=glycolysis_PYK, strategy="simulate",
                            update_initial_conditions=True, 
                            update_reactions=True, **options)

t0, tf = (0, 1e4)
conc_sol, flux_sol = sim.simulate_model(glycolysis_PYK, time=(t0, tf), **options)
conc_sol.preview_time_profile

# %% [markdown]
# ### Storing information and references
# #### Compartment
# Because the character "c" represents the cytosol compartment, it is recommended to define and set the compartment in the <font color=#4682B4>EnzymeModule</font><font color=#1E90FF>.compartments</font> attribute.

# %%
PYK.compartments = {"c": "Cytosol"}
print(PYK.compartments)
# Out:
# {'c': 'Cytosol'}

# %% [markdown]
# #### Units
# All of the units for the numerical values used in this model are "Millimoles" for amount and "Liters" for volume (giving a concentration unit of 'Millimolar'), and "Hours" for time. In order to ensure that future users understand the numerical values for model, it is important to define the <font color=#4682B4>EnzymeModule</font><font color=#1E90FF>.units</font> attribute.
#
# The <font color=#4682B4>EnzymeModule</font><font color=#1E90FF>.units</font> is a <font color=#008000>cobra</font><font color=#556B2F>.DictList</font> that contains only <font color=#4682B4>UnitDefinition</font> objects from the <font color=#0000FF>mass.core.unit</font> submodule.
#
# Each <font color=#4682B4>UnitDefinition</font> is created from <font color=#4682B4>Unit</font> objects representing the base units that comprise the <font color=#4682B4>UnitDefinition</font>. These <font color=#4682B4>Units</font> are stored in the <font color=#1E90FF>list_of_units</font> attribute. Pre-built units can be viewed using the <font color=#00008B>print_defined_unit_values</font> function from the <font color=#0000FF>mass.core.unit</font></td> submodule. Alternatively, custom units can also be created using the <font color=#4682B4>UnitDefinition</font><font color=#00008B>.create_unit</font> function.
#
# For more information about units, please see the module docstring for <font color=#0000FF>mass.core.unit</font> submodule.
#
# __Note:__ It is important to note that this attribute will NOT track units, but instead acts as a reference for the user and others so that they can perform necessary unit conversions.

# %%
# Using pre-build units to define UnitDefinitions
concentration = UnitDefinition(id="mM", name="Millimolar", list_of_units=["millimole", "per_litre"])
time = UnitDefinition(id="hr", name="Hour", list_of_units=["hour"])

# Add units to model
PYK.add_units([concentration, time])
print(PYK.units)
# Out:
# [<UnitDefinition Millimolar at 0x12aaf6d30>, <UnitDefinition Hour at 0x12aaf6a90>]

# %% [markdown]
# ## Export
#
# After validation, the model is ready to be saved. The model can either be exported as a ".json" file or as an ".sbml" (".xml") file using their repsective submodules in <font color=#0000FF>mass.io</font></td>.
#
# To export the model, only the path to the directory and the name of the model need to be specified. Both are shown below.

# %%
filepath = path.realpath(path.join("models", PYK.id))

# %% [markdown]
# ### Export using JSON

# %%
json.save_json_model(mass_model=PYK, filename=filepath + ".json")

# %% [markdown]
# ### Export using SBML

# %%
sbml.write_sbml_model(mass_model=PYK, filename=filepath + ".xml")
# Out:
# adding fbc-V2 package extension
# set fbc package extension required to false
# set SBO term for modeling framework
# create model
# get fbc plugin for model
# set fbc plugin strictness to true
# set model id
# set model meta id
# set model name
# create model parameter for 'kf_R_PYK_L'
# set parameter id for 'kf_R_PYK_L'
# set parameter value for 'kf_R_PYK_L'
# set parameter constant for 'kf_R_PYK_L'
# create model parameter for 'Keq_R_PYK_R05'
# set parameter id for 'Keq_R_PYK_R05'
# set parameter value for 'Keq_R_PYK_R05'
# set parameter constant for 'Keq_R_PYK_R05'
# create model parameter for 'Keq_R_PYK_R15'
# set parameter id for 'Keq_R_PYK_R15'
# set parameter value for 'Keq_R_PYK_R15'
# set parameter constant for 'Keq_R_PYK_R15'
# create model parameter for 'Keq_R_PYK_R25'
# set parameter id for 'Keq_R_PYK_R25'
# set parameter value for 'Keq_R_PYK_R25'
# set parameter constant for 'Keq_R_PYK_R25'
# create model parameter for 'Keq_R_PYK_R35'
# set parameter id for 'Keq_R_PYK_R35'
# set parameter value for 'Keq_R_PYK_R35'
# set parameter constant for 'Keq_R_PYK_R35'
# create model parameter for 'Keq_R_PYK_R45'
# set parameter id for 'Keq_R_PYK_R45'
# set parameter value for 'Keq_R_PYK_R45'
# set parameter constant for 'Keq_R_PYK_R45'
# create model parameter for 'Keq_R_PYK_L'
# set parameter id for 'Keq_R_PYK_L'
# set parameter value for 'Keq_R_PYK_L'
# set parameter constant for 'Keq_R_PYK_L'
# create model parameter for 'Keq_PYK_P'
# set parameter id for 'Keq_PYK_P'
# set parameter value for 'Keq_PYK_P'
# set parameter constant for 'Keq_PYK_P'
# create model parameter for 'Keq_PYK_A'
# set parameter id for 'Keq_PYK_A'
# set parameter value for 'Keq_PYK_A'
# set parameter constant for 'Keq_PYK_A'
# create model parameter for 'Keq_PYK_I'
# set parameter id for 'Keq_PYK_I'
# set parameter value for 'Keq_PYK_I'
# set parameter constant for 'Keq_PYK_I'
# create model parameter for 'Keq_PYK_ACT'
# set parameter id for 'Keq_PYK_ACT'
# set parameter value for 'Keq_PYK_ACT'
# set parameter constant for 'Keq_PYK_ACT'
# create model parameter for 'Keq_R_PYK_L'
# set parameter id for 'Keq_R_PYK_L'
# set parameter value for 'Keq_R_PYK_L'
# set parameter constant for 'Keq_R_PYK_L'
# create model parameter for 'kf_PYK'
# set parameter id for 'kf_PYK'
# set parameter value for 'kf_PYK'
# set parameter constant for 'kf_PYK'
# create model parameter for 'kf_PYK_A'
# set parameter id for 'kf_PYK_A'
# set parameter value for 'kf_PYK_A'
# set parameter constant for 'kf_PYK_A'
# create model parameter for 'kf_PYK_P'
# set parameter id for 'kf_PYK_P'
# set parameter value for 'kf_PYK_P'
# set parameter constant for 'kf_PYK_P'
# create model parameter for 'kf_PYK_I'
# set parameter id for 'kf_PYK_I'
# set parameter value for 'kf_PYK_I'
# set parameter constant for 'kf_PYK_I'
# create model parameter for 'kf_PYK_ACT'
# set parameter id for 'kf_PYK_ACT'
# set parameter value for 'kf_PYK_ACT'
# set parameter constant for 'kf_PYK_ACT'
# create model compartment for 'c'
# set compartment id for 'c'
# set compartment name for 'c'
# set compartment constant for 'c'
# create model specie for 'M_pep_c'
# set specie id for 'M_pep_c'
# set specie name for 'M_pep_c'
# set specie compartment for 'M_pep_c'
# set specie initial concentration for 'M_pep_c'
# set specie constant for 'M_pep_c'
# set specie boundary condition for 'M_pep_c'
# set specie unit substance restrictions for 'M_pep_c'
# get fbc plugin for specie for 'M_pep_c'
# set specie charge for 'M_pep_c'
# set specie formula for 'M_pep_c'
# create model specie for 'M_adp_c'
# set specie id for 'M_adp_c'
# set specie name for 'M_adp_c'
# set specie compartment for 'M_adp_c'
# set specie initial concentration for 'M_adp_c'
# set specie constant for 'M_adp_c'
# set specie boundary condition for 'M_adp_c'
# set specie unit substance restrictions for 'M_adp_c'
# get fbc plugin for specie for 'M_adp_c'
# set specie charge for 'M_adp_c'
# set specie formula for 'M_adp_c'
# create model specie for 'M_fdp_c'
# set specie id for 'M_fdp_c'
# set specie name for 'M_fdp_c'
# set specie compartment for 'M_fdp_c'
# set specie initial concentration for 'M_fdp_c'
# set specie constant for 'M_fdp_c'
# set specie boundary condition for 'M_fdp_c'
# set specie unit substance restrictions for 'M_fdp_c'
# get fbc plugin for specie for 'M_fdp_c'
# set specie charge for 'M_fdp_c'
# set specie formula for 'M_fdp_c'
# create model specie for 'M_atp_c'
# set specie id for 'M_atp_c'
# set specie name for 'M_atp_c'
# set specie compartment for 'M_atp_c'
# set specie initial concentration for 'M_atp_c'
# set specie constant for 'M_atp_c'
# set specie boundary condition for 'M_atp_c'
# set specie unit substance restrictions for 'M_atp_c'
# get fbc plugin for specie for 'M_atp_c'
# set specie charge for 'M_atp_c'
# set specie formula for 'M_atp_c'
# create model specie for 'M_pyr_c'
# set specie id for 'M_pyr_c'
# set specie name for 'M_pyr_c'
# set specie compartment for 'M_pyr_c'
# set specie initial concentration for 'M_pyr_c'
# set specie constant for 'M_pyr_c'
# set specie boundary condition for 'M_pyr_c'
# set specie unit substance restrictions for 'M_pyr_c'
# get fbc plugin for specie for 'M_pyr_c'
# set specie charge for 'M_pyr_c'
# set specie formula for 'M_pyr_c'
# create model specie for 'M_h_c'
# set specie id for 'M_h_c'
# set specie name for 'M_h_c'
# set specie compartment for 'M_h_c'
# set specie initial concentration for 'M_h_c'
# set specie constant for 'M_h_c'
# set specie boundary condition for 'M_h_c'
# set specie unit substance restrictions for 'M_h_c'
# get fbc plugin for specie for 'M_h_c'
# set specie charge for 'M_h_c'
# set specie formula for 'M_h_c'
# create model specie for 'M_pyk_R0_c'
# set specie id for 'M_pyk_R0_c'
# set specie name for 'M_pyk_R0_c'
# set specie compartment for 'M_pyk_R0_c'
# set specie initial concentration for 'M_pyk_R0_c'
# set specie constant for 'M_pyk_R0_c'
# set specie boundary condition for 'M_pyk_R0_c'
# set specie unit substance restrictions for 'M_pyk_R0_c'
# get fbc plugin for specie for 'M_pyk_R0_c'
# set specie charge for 'M_pyk_R0_c'
# set specie formula for 'M_pyk_R0_c'
# create model specie for 'M_pyk_R0_A_c'
# set specie id for 'M_pyk_R0_A_c'
# set specie name for 'M_pyk_R0_A_c'
# set specie compartment for 'M_pyk_R0_A_c'
# set specie initial concentration for 'M_pyk_R0_A_c'
# set specie constant for 'M_pyk_R0_A_c'
# set specie boundary condition for 'M_pyk_R0_A_c'
# set specie unit substance restrictions for 'M_pyk_R0_A_c'
# get fbc plugin for specie for 'M_pyk_R0_A_c'
# set specie charge for 'M_pyk_R0_A_c'
# set specie formula for 'M_pyk_R0_A_c'
# create model specie for 'M_pyk_R0_P_c'
# set specie id for 'M_pyk_R0_P_c'
# set specie name for 'M_pyk_R0_P_c'
# set specie compartment for 'M_pyk_R0_P_c'
# set specie initial concentration for 'M_pyk_R0_P_c'
# set specie constant for 'M_pyk_R0_P_c'
# set specie boundary condition for 'M_pyk_R0_P_c'
# set specie unit substance restrictions for 'M_pyk_R0_P_c'
# get fbc plugin for specie for 'M_pyk_R0_P_c'
# set specie charge for 'M_pyk_R0_P_c'
# set specie formula for 'M_pyk_R0_P_c'
# create model specie for 'M_pyk_R0_AP_c'
# set specie id for 'M_pyk_R0_AP_c'
# set specie name for 'M_pyk_R0_AP_c'
# set specie compartment for 'M_pyk_R0_AP_c'
# set specie initial concentration for 'M_pyk_R0_AP_c'
# set specie constant for 'M_pyk_R0_AP_c'
# set specie boundary condition for 'M_pyk_R0_AP_c'
# set specie unit substance restrictions for 'M_pyk_R0_AP_c'
# get fbc plugin for specie for 'M_pyk_R0_AP_c'
# set specie charge for 'M_pyk_R0_AP_c'
# set specie formula for 'M_pyk_R0_AP_c'
# create model specie for 'M_pyk_T0_c'
# set specie id for 'M_pyk_T0_c'
# set specie name for 'M_pyk_T0_c'
# set specie compartment for 'M_pyk_T0_c'
# set specie initial concentration for 'M_pyk_T0_c'
# set specie constant for 'M_pyk_T0_c'
# set specie boundary condition for 'M_pyk_T0_c'
# set specie unit substance restrictions for 'M_pyk_T0_c'
# get fbc plugin for specie for 'M_pyk_T0_c'
# set specie charge for 'M_pyk_T0_c'
# set specie formula for 'M_pyk_T0_c'
# create model specie for 'M_pyk_R1_c'
# set specie id for 'M_pyk_R1_c'
# set specie name for 'M_pyk_R1_c'
# set specie compartment for 'M_pyk_R1_c'
# set specie initial concentration for 'M_pyk_R1_c'
# set specie constant for 'M_pyk_R1_c'
# set specie boundary condition for 'M_pyk_R1_c'
# set specie unit substance restrictions for 'M_pyk_R1_c'
# get fbc plugin for specie for 'M_pyk_R1_c'
# set specie charge for 'M_pyk_R1_c'
# set specie formula for 'M_pyk_R1_c'
# create model specie for 'M_pyk_R1_A_c'
# set specie id for 'M_pyk_R1_A_c'
# set specie name for 'M_pyk_R1_A_c'
# set specie compartment for 'M_pyk_R1_A_c'
# set specie initial concentration for 'M_pyk_R1_A_c'
# set specie constant for 'M_pyk_R1_A_c'
# set specie boundary condition for 'M_pyk_R1_A_c'
# set specie unit substance restrictions for 'M_pyk_R1_A_c'
# get fbc plugin for specie for 'M_pyk_R1_A_c'
# set specie charge for 'M_pyk_R1_A_c'
# set specie formula for 'M_pyk_R1_A_c'
# create model specie for 'M_pyk_R1_P_c'
# set specie id for 'M_pyk_R1_P_c'
# set specie name for 'M_pyk_R1_P_c'
# set specie compartment for 'M_pyk_R1_P_c'
# set specie initial concentration for 'M_pyk_R1_P_c'
# set specie constant for 'M_pyk_R1_P_c'
# set specie boundary condition for 'M_pyk_R1_P_c'
# set specie unit substance restrictions for 'M_pyk_R1_P_c'
# get fbc plugin for specie for 'M_pyk_R1_P_c'
# set specie charge for 'M_pyk_R1_P_c'
# set specie formula for 'M_pyk_R1_P_c'
# create model specie for 'M_pyk_R1_AP_c'
# set specie id for 'M_pyk_R1_AP_c'
# set specie name for 'M_pyk_R1_AP_c'
# set specie compartment for 'M_pyk_R1_AP_c'
# set specie initial concentration for 'M_pyk_R1_AP_c'
# set specie constant for 'M_pyk_R1_AP_c'
# set specie boundary condition for 'M_pyk_R1_AP_c'
# set specie unit substance restrictions for 'M_pyk_R1_AP_c'
# get fbc plugin for specie for 'M_pyk_R1_AP_c'
# set specie charge for 'M_pyk_R1_AP_c'
# set specie formula for 'M_pyk_R1_AP_c'
# create model specie for 'M_pyk_T1_c'
# set specie id for 'M_pyk_T1_c'
# set specie name for 'M_pyk_T1_c'
# set specie compartment for 'M_pyk_T1_c'
# set specie initial concentration for 'M_pyk_T1_c'
# set specie constant for 'M_pyk_T1_c'
# set specie boundary condition for 'M_pyk_T1_c'
# set specie unit substance restrictions for 'M_pyk_T1_c'
# get fbc plugin for specie for 'M_pyk_T1_c'
# set specie charge for 'M_pyk_T1_c'
# set specie formula for 'M_pyk_T1_c'
# create model specie for 'M_pyk_R2_c'
# set specie id for 'M_pyk_R2_c'
# set specie name for 'M_pyk_R2_c'
# set specie compartment for 'M_pyk_R2_c'
# set specie initial concentration for 'M_pyk_R2_c'
# set specie constant for 'M_pyk_R2_c'
# set specie boundary condition for 'M_pyk_R2_c'
# set specie unit substance restrictions for 'M_pyk_R2_c'
# get fbc plugin for specie for 'M_pyk_R2_c'
# set specie charge for 'M_pyk_R2_c'
# set specie formula for 'M_pyk_R2_c'
# create model specie for 'M_pyk_R2_A_c'
# set specie id for 'M_pyk_R2_A_c'
# set specie name for 'M_pyk_R2_A_c'
# set specie compartment for 'M_pyk_R2_A_c'
# set specie initial concentration for 'M_pyk_R2_A_c'
# set specie constant for 'M_pyk_R2_A_c'
# set specie boundary condition for 'M_pyk_R2_A_c'
# set specie unit substance restrictions for 'M_pyk_R2_A_c'
# get fbc plugin for specie for 'M_pyk_R2_A_c'
# set specie charge for 'M_pyk_R2_A_c'
# set specie formula for 'M_pyk_R2_A_c'
# create model specie for 'M_pyk_R2_P_c'
# set specie id for 'M_pyk_R2_P_c'
# set specie name for 'M_pyk_R2_P_c'
# set specie compartment for 'M_pyk_R2_P_c'
# set specie initial concentration for 'M_pyk_R2_P_c'
# set specie constant for 'M_pyk_R2_P_c'
# set specie boundary condition for 'M_pyk_R2_P_c'
# set specie unit substance restrictions for 'M_pyk_R2_P_c'
# get fbc plugin for specie for 'M_pyk_R2_P_c'
# set specie charge for 'M_pyk_R2_P_c'
# set specie formula for 'M_pyk_R2_P_c'
# create model specie for 'M_pyk_R2_AP_c'
# set specie id for 'M_pyk_R2_AP_c'
# set specie name for 'M_pyk_R2_AP_c'
# set specie compartment for 'M_pyk_R2_AP_c'
# set specie initial concentration for 'M_pyk_R2_AP_c'
# set specie constant for 'M_pyk_R2_AP_c'
# set specie boundary condition for 'M_pyk_R2_AP_c'
# set specie unit substance restrictions for 'M_pyk_R2_AP_c'
# get fbc plugin for specie for 'M_pyk_R2_AP_c'
# set specie charge for 'M_pyk_R2_AP_c'
# set specie formula for 'M_pyk_R2_AP_c'
# create model specie for 'M_pyk_T2_c'
# set specie id for 'M_pyk_T2_c'
# set specie name for 'M_pyk_T2_c'
# set specie compartment for 'M_pyk_T2_c'
# set specie initial concentration for 'M_pyk_T2_c'
# set specie constant for 'M_pyk_T2_c'
# set specie boundary condition for 'M_pyk_T2_c'
# set specie unit substance restrictions for 'M_pyk_T2_c'
# get fbc plugin for specie for 'M_pyk_T2_c'
# set specie charge for 'M_pyk_T2_c'
# set specie formula for 'M_pyk_T2_c'
# create model specie for 'M_pyk_R3_c'
# set specie id for 'M_pyk_R3_c'
# set specie name for 'M_pyk_R3_c'
# set specie compartment for 'M_pyk_R3_c'
# set specie initial concentration for 'M_pyk_R3_c'
# set specie constant for 'M_pyk_R3_c'
# set specie boundary condition for 'M_pyk_R3_c'
# set specie unit substance restrictions for 'M_pyk_R3_c'
# get fbc plugin for specie for 'M_pyk_R3_c'
# set specie charge for 'M_pyk_R3_c'
# set specie formula for 'M_pyk_R3_c'
# create model specie for 'M_pyk_R3_A_c'
# set specie id for 'M_pyk_R3_A_c'
# set specie name for 'M_pyk_R3_A_c'
# set specie compartment for 'M_pyk_R3_A_c'
# set specie initial concentration for 'M_pyk_R3_A_c'
# set specie constant for 'M_pyk_R3_A_c'
# set specie boundary condition for 'M_pyk_R3_A_c'
# set specie unit substance restrictions for 'M_pyk_R3_A_c'
# get fbc plugin for specie for 'M_pyk_R3_A_c'
# set specie charge for 'M_pyk_R3_A_c'
# set specie formula for 'M_pyk_R3_A_c'
# create model specie for 'M_pyk_R3_P_c'
# set specie id for 'M_pyk_R3_P_c'
# set specie name for 'M_pyk_R3_P_c'
# set specie compartment for 'M_pyk_R3_P_c'
# set specie initial concentration for 'M_pyk_R3_P_c'
# set specie constant for 'M_pyk_R3_P_c'
# set specie boundary condition for 'M_pyk_R3_P_c'
# set specie unit substance restrictions for 'M_pyk_R3_P_c'
# get fbc plugin for specie for 'M_pyk_R3_P_c'
# set specie charge for 'M_pyk_R3_P_c'
# set specie formula for 'M_pyk_R3_P_c'
# create model specie for 'M_pyk_R3_AP_c'
# set specie id for 'M_pyk_R3_AP_c'
# set specie name for 'M_pyk_R3_AP_c'
# set specie compartment for 'M_pyk_R3_AP_c'
# set specie initial concentration for 'M_pyk_R3_AP_c'
# set specie constant for 'M_pyk_R3_AP_c'
# set specie boundary condition for 'M_pyk_R3_AP_c'
# set specie unit substance restrictions for 'M_pyk_R3_AP_c'
# get fbc plugin for specie for 'M_pyk_R3_AP_c'
# set specie charge for 'M_pyk_R3_AP_c'
# set specie formula for 'M_pyk_R3_AP_c'
# create model specie for 'M_pyk_T3_c'
# set specie id for 'M_pyk_T3_c'
# set specie name for 'M_pyk_T3_c'
# set specie compartment for 'M_pyk_T3_c'
# set specie initial concentration for 'M_pyk_T3_c'
# set specie constant for 'M_pyk_T3_c'
# set specie boundary condition for 'M_pyk_T3_c'
# set specie unit substance restrictions for 'M_pyk_T3_c'
# get fbc plugin for specie for 'M_pyk_T3_c'
# set specie charge for 'M_pyk_T3_c'
# set specie formula for 'M_pyk_T3_c'
# create model specie for 'M_pyk_R4_c'
# set specie id for 'M_pyk_R4_c'
# set specie name for 'M_pyk_R4_c'
# set specie compartment for 'M_pyk_R4_c'
# set specie initial concentration for 'M_pyk_R4_c'
# set specie constant for 'M_pyk_R4_c'
# set specie boundary condition for 'M_pyk_R4_c'
# set specie unit substance restrictions for 'M_pyk_R4_c'
# get fbc plugin for specie for 'M_pyk_R4_c'
# set specie charge for 'M_pyk_R4_c'
# set specie formula for 'M_pyk_R4_c'
# create model specie for 'M_pyk_R4_A_c'
# set specie id for 'M_pyk_R4_A_c'
# set specie name for 'M_pyk_R4_A_c'
# set specie compartment for 'M_pyk_R4_A_c'
# set specie initial concentration for 'M_pyk_R4_A_c'
# set specie constant for 'M_pyk_R4_A_c'
# set specie boundary condition for 'M_pyk_R4_A_c'
# set specie unit substance restrictions for 'M_pyk_R4_A_c'
# get fbc plugin for specie for 'M_pyk_R4_A_c'
# set specie charge for 'M_pyk_R4_A_c'
# set specie formula for 'M_pyk_R4_A_c'
# create model specie for 'M_pyk_R4_P_c'
# set specie id for 'M_pyk_R4_P_c'
# set specie name for 'M_pyk_R4_P_c'
# set specie compartment for 'M_pyk_R4_P_c'
# set specie initial concentration for 'M_pyk_R4_P_c'
# set specie constant for 'M_pyk_R4_P_c'
# set specie boundary condition for 'M_pyk_R4_P_c'
# set specie unit substance restrictions for 'M_pyk_R4_P_c'
# get fbc plugin for specie for 'M_pyk_R4_P_c'
# set specie charge for 'M_pyk_R4_P_c'
# set specie formula for 'M_pyk_R4_P_c'
# create model specie for 'M_pyk_R4_AP_c'
# set specie id for 'M_pyk_R4_AP_c'
# set specie name for 'M_pyk_R4_AP_c'
# set specie compartment for 'M_pyk_R4_AP_c'
# set specie initial concentration for 'M_pyk_R4_AP_c'
# set specie constant for 'M_pyk_R4_AP_c'
# set specie boundary condition for 'M_pyk_R4_AP_c'
# set specie unit substance restrictions for 'M_pyk_R4_AP_c'
# get fbc plugin for specie for 'M_pyk_R4_AP_c'
# set specie charge for 'M_pyk_R4_AP_c'
# set specie formula for 'M_pyk_R4_AP_c'
# create model specie for 'M_pyk_T4_c'
# set specie id for 'M_pyk_T4_c'
# set specie name for 'M_pyk_T4_c'
# set specie compartment for 'M_pyk_T4_c'
# set specie initial concentration for 'M_pyk_T4_c'
# set specie constant for 'M_pyk_T4_c'
# set specie boundary condition for 'M_pyk_T4_c'
# set specie unit substance restrictions for 'M_pyk_T4_c'
# get fbc plugin for specie for 'M_pyk_T4_c'
# set specie charge for 'M_pyk_T4_c'
# set specie formula for 'M_pyk_T4_c'
# create reaction for 'R_PYK_R01'
# set reaction id for 'R_PYK_R01'
# set reaction name for 'R_PYK_R01'
# set reaction reversible for 'R_PYK_R01'
# create specie reference M_pyk_R0_c for 'R_PYK_R01'
# set specie reference id for 'M_pyk_R0_c'
# set specie reference stoichiometry for 'M_pyk_R0_c'
# set specie reference constant for 'M_pyk_R0_c'
# create specie reference M_pep_c for 'R_PYK_R01'
# set specie reference id for 'M_pep_c'
# set specie reference stoichiometry for 'M_pep_c'
# set specie reference constant for 'M_pep_c'
# create specie reference M_pyk_R0_P_c for 'R_PYK_R01'
# set specie reference id for 'M_pyk_R0_P_c'
# set specie reference stoichiometry for 'M_pyk_R0_P_c'
# set specie reference constant for 'M_pyk_R0_P_c'
# get fbc plugin for reaction for 'R_PYK_R01'
# create kinetic law for 'R_PYK_R01'
# set math on kinetic law for 'R_PYK_R01'
# create reaction for 'R_PYK_R02'
# set reaction id for 'R_PYK_R02'
# set reaction name for 'R_PYK_R02'
# set reaction reversible for 'R_PYK_R02'
# create specie reference M_pyk_R0_c for 'R_PYK_R02'
# set specie reference id for 'M_pyk_R0_c'
# set specie reference stoichiometry for 'M_pyk_R0_c'
# set specie reference constant for 'M_pyk_R0_c'
# create specie reference M_adp_c for 'R_PYK_R02'
# set specie reference id for 'M_adp_c'
# set specie reference stoichiometry for 'M_adp_c'
# set specie reference constant for 'M_adp_c'
# create specie reference M_pyk_R0_A_c for 'R_PYK_R02'
# set specie reference id for 'M_pyk_R0_A_c'
# set specie reference stoichiometry for 'M_pyk_R0_A_c'
# set specie reference constant for 'M_pyk_R0_A_c'
# get fbc plugin for reaction for 'R_PYK_R02'
# create kinetic law for 'R_PYK_R02'
# set math on kinetic law for 'R_PYK_R02'
# create reaction for 'R_PYK_R03'
# set reaction id for 'R_PYK_R03'
# set reaction name for 'R_PYK_R03'
# set reaction reversible for 'R_PYK_R03'
# create specie reference M_pyk_R0_A_c for 'R_PYK_R03'
# set specie reference id for 'M_pyk_R0_A_c'
# set specie reference stoichiometry for 'M_pyk_R0_A_c'
# set specie reference constant for 'M_pyk_R0_A_c'
# create specie reference M_pep_c for 'R_PYK_R03'
# set specie reference id for 'M_pep_c'
# set specie reference stoichiometry for 'M_pep_c'
# set specie reference constant for 'M_pep_c'
# create specie reference M_pyk_R0_AP_c for 'R_PYK_R03'
# set specie reference id for 'M_pyk_R0_AP_c'
# set specie reference stoichiometry for 'M_pyk_R0_AP_c'
# set specie reference constant for 'M_pyk_R0_AP_c'
# get fbc plugin for reaction for 'R_PYK_R03'
# create kinetic law for 'R_PYK_R03'
# set math on kinetic law for 'R_PYK_R03'
# create reaction for 'R_PYK_R04'
# set reaction id for 'R_PYK_R04'
# set reaction name for 'R_PYK_R04'
# set reaction reversible for 'R_PYK_R04'
# create specie reference M_pyk_R0_P_c for 'R_PYK_R04'
# set specie reference id for 'M_pyk_R0_P_c'
# set specie reference stoichiometry for 'M_pyk_R0_P_c'
# set specie reference constant for 'M_pyk_R0_P_c'
# create specie reference M_adp_c for 'R_PYK_R04'
# set specie reference id for 'M_adp_c'
# set specie reference stoichiometry for 'M_adp_c'
# set specie reference constant for 'M_adp_c'
# create specie reference M_pyk_R0_AP_c for 'R_PYK_R04'
# set specie reference id for 'M_pyk_R0_AP_c'
# set specie reference stoichiometry for 'M_pyk_R0_AP_c'
# set specie reference constant for 'M_pyk_R0_AP_c'
# get fbc plugin for reaction for 'R_PYK_R04'
# create kinetic law for 'R_PYK_R04'
# set math on kinetic law for 'R_PYK_R04'
# create reaction for 'R_PYK_R05'
# set reaction id for 'R_PYK_R05'
# set reaction name for 'R_PYK_R05'
# set reaction reversible for 'R_PYK_R05'
# create specie reference M_pyk_R0_AP_c for 'R_PYK_R05'
# set specie reference id for 'M_pyk_R0_AP_c'
# set specie reference stoichiometry for 'M_pyk_R0_AP_c'
# set specie reference constant for 'M_pyk_R0_AP_c'
# create specie reference M_h_c for 'R_PYK_R05'
# set specie reference id for 'M_h_c'
# set specie reference stoichiometry for 'M_h_c'
# set specie reference constant for 'M_h_c'
# create specie reference M_pyk_R0_c for 'R_PYK_R05'
# set specie reference id for 'M_pyk_R0_c'
# set specie reference stoichiometry for 'M_pyk_R0_c'
# set specie reference constant for 'M_pyk_R0_c'
# create specie reference M_atp_c for 'R_PYK_R05'
# set specie reference id for 'M_atp_c'
# set specie reference stoichiometry for 'M_atp_c'
# set specie reference constant for 'M_atp_c'
# create specie reference M_pyr_c for 'R_PYK_R05'
# set specie reference id for 'M_pyr_c'
# set specie reference stoichiometry for 'M_pyr_c'
# set specie reference constant for 'M_pyr_c'
# get fbc plugin for reaction for 'R_PYK_R05'
# create kinetic law for 'R_PYK_R05'
# set math on kinetic law for 'R_PYK_R05'
# create reaction for 'R_PYK_R10'
# set reaction id for 'R_PYK_R10'
# set reaction name for 'R_PYK_R10'
# set reaction reversible for 'R_PYK_R10'
# create specie reference M_pyk_R0_c for 'R_PYK_R10'
# set specie reference id for 'M_pyk_R0_c'
# set specie reference stoichiometry for 'M_pyk_R0_c'
# set specie reference constant for 'M_pyk_R0_c'
# create specie reference M_fdp_c for 'R_PYK_R10'
# set specie reference id for 'M_fdp_c'
# set specie reference stoichiometry for 'M_fdp_c'
# set specie reference constant for 'M_fdp_c'
# create specie reference M_pyk_R1_c for 'R_PYK_R10'
# set specie reference id for 'M_pyk_R1_c'
# set specie reference stoichiometry for 'M_pyk_R1_c'
# set specie reference constant for 'M_pyk_R1_c'
# get fbc plugin for reaction for 'R_PYK_R10'
# create kinetic law for 'R_PYK_R10'
# set math on kinetic law for 'R_PYK_R10'
# create reaction for 'R_PYK_R11'
# set reaction id for 'R_PYK_R11'
# set reaction name for 'R_PYK_R11'
# set reaction reversible for 'R_PYK_R11'
# create specie reference M_pyk_R1_c for 'R_PYK_R11'
# set specie reference id for 'M_pyk_R1_c'
# set specie reference stoichiometry for 'M_pyk_R1_c'
# set specie reference constant for 'M_pyk_R1_c'
# create specie reference M_pep_c for 'R_PYK_R11'
# set specie reference id for 'M_pep_c'
# set specie reference stoichiometry for 'M_pep_c'
# set specie reference constant for 'M_pep_c'
# create specie reference M_pyk_R1_P_c for 'R_PYK_R11'
# set specie reference id for 'M_pyk_R1_P_c'
# set specie reference stoichiometry for 'M_pyk_R1_P_c'
# set specie reference constant for 'M_pyk_R1_P_c'
# get fbc plugin for reaction for 'R_PYK_R11'
# create kinetic law for 'R_PYK_R11'
# set math on kinetic law for 'R_PYK_R11'
# create reaction for 'R_PYK_R12'
# set reaction id for 'R_PYK_R12'
# set reaction name for 'R_PYK_R12'
# set reaction reversible for 'R_PYK_R12'
# create specie reference M_pyk_R1_c for 'R_PYK_R12'
# set specie reference id for 'M_pyk_R1_c'
# set specie reference stoichiometry for 'M_pyk_R1_c'
# set specie reference constant for 'M_pyk_R1_c'
# create specie reference M_adp_c for 'R_PYK_R12'
# set specie reference id for 'M_adp_c'
# set specie reference stoichiometry for 'M_adp_c'
# set specie reference constant for 'M_adp_c'
# create specie reference M_pyk_R1_A_c for 'R_PYK_R12'
# set specie reference id for 'M_pyk_R1_A_c'
# set specie reference stoichiometry for 'M_pyk_R1_A_c'
# set specie reference constant for 'M_pyk_R1_A_c'
# get fbc plugin for reaction for 'R_PYK_R12'
# create kinetic law for 'R_PYK_R12'
# set math on kinetic law for 'R_PYK_R12'
# create reaction for 'R_PYK_R13'
# set reaction id for 'R_PYK_R13'
# set reaction name for 'R_PYK_R13'
# set reaction reversible for 'R_PYK_R13'
# create specie reference M_pyk_R1_A_c for 'R_PYK_R13'
# set specie reference id for 'M_pyk_R1_A_c'
# set specie reference stoichiometry for 'M_pyk_R1_A_c'
# set specie reference constant for 'M_pyk_R1_A_c'
# create specie reference M_pep_c for 'R_PYK_R13'
# set specie reference id for 'M_pep_c'
# set specie reference stoichiometry for 'M_pep_c'
# set specie reference constant for 'M_pep_c'
# create specie reference M_pyk_R1_AP_c for 'R_PYK_R13'
# set specie reference id for 'M_pyk_R1_AP_c'
# set specie reference stoichiometry for 'M_pyk_R1_AP_c'
# set specie reference constant for 'M_pyk_R1_AP_c'
# get fbc plugin for reaction for 'R_PYK_R13'
# create kinetic law for 'R_PYK_R13'
# set math on kinetic law for 'R_PYK_R13'
# create reaction for 'R_PYK_R14'
# set reaction id for 'R_PYK_R14'
# set reaction name for 'R_PYK_R14'
# set reaction reversible for 'R_PYK_R14'
# create specie reference M_pyk_R1_P_c for 'R_PYK_R14'
# set specie reference id for 'M_pyk_R1_P_c'
# set specie reference stoichiometry for 'M_pyk_R1_P_c'
# set specie reference constant for 'M_pyk_R1_P_c'
# create specie reference M_adp_c for 'R_PYK_R14'
# set specie reference id for 'M_adp_c'
# set specie reference stoichiometry for 'M_adp_c'
# set specie reference constant for 'M_adp_c'
# create specie reference M_pyk_R1_AP_c for 'R_PYK_R14'
# set specie reference id for 'M_pyk_R1_AP_c'
# set specie reference stoichiometry for 'M_pyk_R1_AP_c'
# set specie reference constant for 'M_pyk_R1_AP_c'
# get fbc plugin for reaction for 'R_PYK_R14'
# create kinetic law for 'R_PYK_R14'
# set math on kinetic law for 'R_PYK_R14'
# create reaction for 'R_PYK_R15'
# set reaction id for 'R_PYK_R15'
# set reaction name for 'R_PYK_R15'
# set reaction reversible for 'R_PYK_R15'
# create specie reference M_pyk_R1_AP_c for 'R_PYK_R15'
# set specie reference id for 'M_pyk_R1_AP_c'
# set specie reference stoichiometry for 'M_pyk_R1_AP_c'
# set specie reference constant for 'M_pyk_R1_AP_c'
# create specie reference M_h_c for 'R_PYK_R15'
# set specie reference id for 'M_h_c'
# set specie reference stoichiometry for 'M_h_c'
# set specie reference constant for 'M_h_c'
# create specie reference M_pyk_R1_c for 'R_PYK_R15'
# set specie reference id for 'M_pyk_R1_c'
# set specie reference stoichiometry for 'M_pyk_R1_c'
# set specie reference constant for 'M_pyk_R1_c'
# create specie reference M_atp_c for 'R_PYK_R15'
# set specie reference id for 'M_atp_c'
# set specie reference stoichiometry for 'M_atp_c'
# set specie reference constant for 'M_atp_c'
# create specie reference M_pyr_c for 'R_PYK_R15'
# set specie reference id for 'M_pyr_c'
# set specie reference stoichiometry for 'M_pyr_c'
# set specie reference constant for 'M_pyr_c'
# get fbc plugin for reaction for 'R_PYK_R15'
# create kinetic law for 'R_PYK_R15'
# set math on kinetic law for 'R_PYK_R15'
# create reaction for 'R_PYK_R20'
# set reaction id for 'R_PYK_R20'
# set reaction name for 'R_PYK_R20'
# set reaction reversible for 'R_PYK_R20'
# create specie reference M_pyk_R1_c for 'R_PYK_R20'
# set specie reference id for 'M_pyk_R1_c'
# set specie reference stoichiometry for 'M_pyk_R1_c'
# set specie reference constant for 'M_pyk_R1_c'
# create specie reference M_fdp_c for 'R_PYK_R20'
# set specie reference id for 'M_fdp_c'
# set specie reference stoichiometry for 'M_fdp_c'
# set specie reference constant for 'M_fdp_c'
# create specie reference M_pyk_R2_c for 'R_PYK_R20'
# set specie reference id for 'M_pyk_R2_c'
# set specie reference stoichiometry for 'M_pyk_R2_c'
# set specie reference constant for 'M_pyk_R2_c'
# get fbc plugin for reaction for 'R_PYK_R20'
# create kinetic law for 'R_PYK_R20'
# set math on kinetic law for 'R_PYK_R20'
# create reaction for 'R_PYK_R21'
# set reaction id for 'R_PYK_R21'
# set reaction name for 'R_PYK_R21'
# set reaction reversible for 'R_PYK_R21'
# create specie reference M_pyk_R2_c for 'R_PYK_R21'
# set specie reference id for 'M_pyk_R2_c'
# set specie reference stoichiometry for 'M_pyk_R2_c'
# set specie reference constant for 'M_pyk_R2_c'
# create specie reference M_pep_c for 'R_PYK_R21'
# set specie reference id for 'M_pep_c'
# set specie reference stoichiometry for 'M_pep_c'
# set specie reference constant for 'M_pep_c'
# create specie reference M_pyk_R2_P_c for 'R_PYK_R21'
# set specie reference id for 'M_pyk_R2_P_c'
# set specie reference stoichiometry for 'M_pyk_R2_P_c'
# set specie reference constant for 'M_pyk_R2_P_c'
# get fbc plugin for reaction for 'R_PYK_R21'
# create kinetic law for 'R_PYK_R21'
# set math on kinetic law for 'R_PYK_R21'
# create reaction for 'R_PYK_R22'
# set reaction id for 'R_PYK_R22'
# set reaction name for 'R_PYK_R22'
# set reaction reversible for 'R_PYK_R22'
# create specie reference M_pyk_R2_c for 'R_PYK_R22'
# set specie reference id for 'M_pyk_R2_c'
# set specie reference stoichiometry for 'M_pyk_R2_c'
# set specie reference constant for 'M_pyk_R2_c'
# create specie reference M_adp_c for 'R_PYK_R22'
# set specie reference id for 'M_adp_c'
# set specie reference stoichiometry for 'M_adp_c'
# set specie reference constant for 'M_adp_c'
# create specie reference M_pyk_R2_A_c for 'R_PYK_R22'
# set specie reference id for 'M_pyk_R2_A_c'
# set specie reference stoichiometry for 'M_pyk_R2_A_c'
# set specie reference constant for 'M_pyk_R2_A_c'
# get fbc plugin for reaction for 'R_PYK_R22'
# create kinetic law for 'R_PYK_R22'
# set math on kinetic law for 'R_PYK_R22'
# create reaction for 'R_PYK_R23'
# set reaction id for 'R_PYK_R23'
# set reaction name for 'R_PYK_R23'
# set reaction reversible for 'R_PYK_R23'
# create specie reference M_pyk_R2_A_c for 'R_PYK_R23'
# set specie reference id for 'M_pyk_R2_A_c'
# set specie reference stoichiometry for 'M_pyk_R2_A_c'
# set specie reference constant for 'M_pyk_R2_A_c'
# create specie reference M_pep_c for 'R_PYK_R23'
# set specie reference id for 'M_pep_c'
# set specie reference stoichiometry for 'M_pep_c'
# set specie reference constant for 'M_pep_c'
# create specie reference M_pyk_R2_AP_c for 'R_PYK_R23'
# set specie reference id for 'M_pyk_R2_AP_c'
# set specie reference stoichiometry for 'M_pyk_R2_AP_c'
# set specie reference constant for 'M_pyk_R2_AP_c'
# get fbc plugin for reaction for 'R_PYK_R23'
# create kinetic law for 'R_PYK_R23'
# set math on kinetic law for 'R_PYK_R23'
# create reaction for 'R_PYK_R24'
# set reaction id for 'R_PYK_R24'
# set reaction name for 'R_PYK_R24'
# set reaction reversible for 'R_PYK_R24'
# create specie reference M_pyk_R2_P_c for 'R_PYK_R24'
# set specie reference id for 'M_pyk_R2_P_c'
# set specie reference stoichiometry for 'M_pyk_R2_P_c'
# set specie reference constant for 'M_pyk_R2_P_c'
# create specie reference M_adp_c for 'R_PYK_R24'
# set specie reference id for 'M_adp_c'
# set specie reference stoichiometry for 'M_adp_c'
# set specie reference constant for 'M_adp_c'
# create specie reference M_pyk_R2_AP_c for 'R_PYK_R24'
# set specie reference id for 'M_pyk_R2_AP_c'
# set specie reference stoichiometry for 'M_pyk_R2_AP_c'
# set specie reference constant for 'M_pyk_R2_AP_c'
# get fbc plugin for reaction for 'R_PYK_R24'
# create kinetic law for 'R_PYK_R24'
# set math on kinetic law for 'R_PYK_R24'
# create reaction for 'R_PYK_R25'
# set reaction id for 'R_PYK_R25'
# set reaction name for 'R_PYK_R25'
# set reaction reversible for 'R_PYK_R25'
# create specie reference M_pyk_R2_AP_c for 'R_PYK_R25'
# set specie reference id for 'M_pyk_R2_AP_c'
# set specie reference stoichiometry for 'M_pyk_R2_AP_c'
# set specie reference constant for 'M_pyk_R2_AP_c'
# create specie reference M_h_c for 'R_PYK_R25'
# set specie reference id for 'M_h_c'
# set specie reference stoichiometry for 'M_h_c'
# set specie reference constant for 'M_h_c'
# create specie reference M_pyk_R2_c for 'R_PYK_R25'
# set specie reference id for 'M_pyk_R2_c'
# set specie reference stoichiometry for 'M_pyk_R2_c'
# set specie reference constant for 'M_pyk_R2_c'
# create specie reference M_atp_c for 'R_PYK_R25'
# set specie reference id for 'M_atp_c'
# set specie reference stoichiometry for 'M_atp_c'
# set specie reference constant for 'M_atp_c'
# create specie reference M_pyr_c for 'R_PYK_R25'
# set specie reference id for 'M_pyr_c'
# set specie reference stoichiometry for 'M_pyr_c'
# set specie reference constant for 'M_pyr_c'
# get fbc plugin for reaction for 'R_PYK_R25'
# create kinetic law for 'R_PYK_R25'
# set math on kinetic law for 'R_PYK_R25'
# create reaction for 'R_PYK_R30'
# set reaction id for 'R_PYK_R30'
# set reaction name for 'R_PYK_R30'
# set reaction reversible for 'R_PYK_R30'
# create specie reference M_pyk_R2_c for 'R_PYK_R30'
# set specie reference id for 'M_pyk_R2_c'
# set specie reference stoichiometry for 'M_pyk_R2_c'
# set specie reference constant for 'M_pyk_R2_c'
# create specie reference M_fdp_c for 'R_PYK_R30'
# set specie reference id for 'M_fdp_c'
# set specie reference stoichiometry for 'M_fdp_c'
# set specie reference constant for 'M_fdp_c'
# create specie reference M_pyk_R3_c for 'R_PYK_R30'
# set specie reference id for 'M_pyk_R3_c'
# set specie reference stoichiometry for 'M_pyk_R3_c'
# set specie reference constant for 'M_pyk_R3_c'
# get fbc plugin for reaction for 'R_PYK_R30'
# create kinetic law for 'R_PYK_R30'
# set math on kinetic law for 'R_PYK_R30'
# create reaction for 'R_PYK_R31'
# set reaction id for 'R_PYK_R31'
# set reaction name for 'R_PYK_R31'
# set reaction reversible for 'R_PYK_R31'
# create specie reference M_pyk_R3_c for 'R_PYK_R31'
# set specie reference id for 'M_pyk_R3_c'
# set specie reference stoichiometry for 'M_pyk_R3_c'
# set specie reference constant for 'M_pyk_R3_c'
# create specie reference M_pep_c for 'R_PYK_R31'
# set specie reference id for 'M_pep_c'
# set specie reference stoichiometry for 'M_pep_c'
# set specie reference constant for 'M_pep_c'
# create specie reference M_pyk_R3_P_c for 'R_PYK_R31'
# set specie reference id for 'M_pyk_R3_P_c'
# set specie reference stoichiometry for 'M_pyk_R3_P_c'
# set specie reference constant for 'M_pyk_R3_P_c'
# get fbc plugin for reaction for 'R_PYK_R31'
# create kinetic law for 'R_PYK_R31'
# set math on kinetic law for 'R_PYK_R31'
# create reaction for 'R_PYK_R32'
# set reaction id for 'R_PYK_R32'
# set reaction name for 'R_PYK_R32'
# set reaction reversible for 'R_PYK_R32'
# create specie reference M_pyk_R3_c for 'R_PYK_R32'
# set specie reference id for 'M_pyk_R3_c'
# set specie reference stoichiometry for 'M_pyk_R3_c'
# set specie reference constant for 'M_pyk_R3_c'
# create specie reference M_adp_c for 'R_PYK_R32'
# set specie reference id for 'M_adp_c'
# set specie reference stoichiometry for 'M_adp_c'
# set specie reference constant for 'M_adp_c'
# create specie reference M_pyk_R3_A_c for 'R_PYK_R32'
# set specie reference id for 'M_pyk_R3_A_c'
# set specie reference stoichiometry for 'M_pyk_R3_A_c'
# set specie reference constant for 'M_pyk_R3_A_c'
# get fbc plugin for reaction for 'R_PYK_R32'
# create kinetic law for 'R_PYK_R32'
# set math on kinetic law for 'R_PYK_R32'
# create reaction for 'R_PYK_R33'
# set reaction id for 'R_PYK_R33'
# set reaction name for 'R_PYK_R33'
# set reaction reversible for 'R_PYK_R33'
# create specie reference M_pyk_R3_A_c for 'R_PYK_R33'
# set specie reference id for 'M_pyk_R3_A_c'
# set specie reference stoichiometry for 'M_pyk_R3_A_c'
# set specie reference constant for 'M_pyk_R3_A_c'
# create specie reference M_pep_c for 'R_PYK_R33'
# set specie reference id for 'M_pep_c'
# set specie reference stoichiometry for 'M_pep_c'
# set specie reference constant for 'M_pep_c'
# create specie reference M_pyk_R3_AP_c for 'R_PYK_R33'
# set specie reference id for 'M_pyk_R3_AP_c'
# set specie reference stoichiometry for 'M_pyk_R3_AP_c'
# set specie reference constant for 'M_pyk_R3_AP_c'
# get fbc plugin for reaction for 'R_PYK_R33'
# create kinetic law for 'R_PYK_R33'
# set math on kinetic law for 'R_PYK_R33'
# create reaction for 'R_PYK_R34'
# set reaction id for 'R_PYK_R34'
# set reaction name for 'R_PYK_R34'
# set reaction reversible for 'R_PYK_R34'
# create specie reference M_pyk_R3_P_c for 'R_PYK_R34'
# set specie reference id for 'M_pyk_R3_P_c'
# set specie reference stoichiometry for 'M_pyk_R3_P_c'
# set specie reference constant for 'M_pyk_R3_P_c'
# create specie reference M_adp_c for 'R_PYK_R34'
# set specie reference id for 'M_adp_c'
# set specie reference stoichiometry for 'M_adp_c'
# set specie reference constant for 'M_adp_c'
# create specie reference M_pyk_R3_AP_c for 'R_PYK_R34'
# set specie reference id for 'M_pyk_R3_AP_c'
# set specie reference stoichiometry for 'M_pyk_R3_AP_c'
# set specie reference constant for 'M_pyk_R3_AP_c'
# get fbc plugin for reaction for 'R_PYK_R34'
# create kinetic law for 'R_PYK_R34'
# set math on kinetic law for 'R_PYK_R34'
# create reaction for 'R_PYK_R35'
# set reaction id for 'R_PYK_R35'
# set reaction name for 'R_PYK_R35'
# set reaction reversible for 'R_PYK_R35'
# create specie reference M_pyk_R3_AP_c for 'R_PYK_R35'
# set specie reference id for 'M_pyk_R3_AP_c'
# set specie reference stoichiometry for 'M_pyk_R3_AP_c'
# set specie reference constant for 'M_pyk_R3_AP_c'
# create specie reference M_h_c for 'R_PYK_R35'
# set specie reference id for 'M_h_c'
# set specie reference stoichiometry for 'M_h_c'
# set specie reference constant for 'M_h_c'
# create specie reference M_pyk_R3_c for 'R_PYK_R35'
# set specie reference id for 'M_pyk_R3_c'
# set specie reference stoichiometry for 'M_pyk_R3_c'
# set specie reference constant for 'M_pyk_R3_c'
# create specie reference M_atp_c for 'R_PYK_R35'
# set specie reference id for 'M_atp_c'
# set specie reference stoichiometry for 'M_atp_c'
# set specie reference constant for 'M_atp_c'
# create specie reference M_pyr_c for 'R_PYK_R35'
# set specie reference id for 'M_pyr_c'
# set specie reference stoichiometry for 'M_pyr_c'
# set specie reference constant for 'M_pyr_c'
# get fbc plugin for reaction for 'R_PYK_R35'
# create kinetic law for 'R_PYK_R35'
# set math on kinetic law for 'R_PYK_R35'
# create reaction for 'R_PYK_R40'
# set reaction id for 'R_PYK_R40'
# set reaction name for 'R_PYK_R40'
# set reaction reversible for 'R_PYK_R40'
# create specie reference M_pyk_R3_c for 'R_PYK_R40'
# set specie reference id for 'M_pyk_R3_c'
# set specie reference stoichiometry for 'M_pyk_R3_c'
# set specie reference constant for 'M_pyk_R3_c'
# create specie reference M_fdp_c for 'R_PYK_R40'
# set specie reference id for 'M_fdp_c'
# set specie reference stoichiometry for 'M_fdp_c'
# set specie reference constant for 'M_fdp_c'
# create specie reference M_pyk_R4_c for 'R_PYK_R40'
# set specie reference id for 'M_pyk_R4_c'
# set specie reference stoichiometry for 'M_pyk_R4_c'
# set specie reference constant for 'M_pyk_R4_c'
# get fbc plugin for reaction for 'R_PYK_R40'
# create kinetic law for 'R_PYK_R40'
# set math on kinetic law for 'R_PYK_R40'
# create reaction for 'R_PYK_R41'
# set reaction id for 'R_PYK_R41'
# set reaction name for 'R_PYK_R41'
# set reaction reversible for 'R_PYK_R41'
# create specie reference M_pyk_R4_c for 'R_PYK_R41'
# set specie reference id for 'M_pyk_R4_c'
# set specie reference stoichiometry for 'M_pyk_R4_c'
# set specie reference constant for 'M_pyk_R4_c'
# create specie reference M_pep_c for 'R_PYK_R41'
# set specie reference id for 'M_pep_c'
# set specie reference stoichiometry for 'M_pep_c'
# set specie reference constant for 'M_pep_c'
# create specie reference M_pyk_R4_P_c for 'R_PYK_R41'
# set specie reference id for 'M_pyk_R4_P_c'
# set specie reference stoichiometry for 'M_pyk_R4_P_c'
# set specie reference constant for 'M_pyk_R4_P_c'
# get fbc plugin for reaction for 'R_PYK_R41'
# create kinetic law for 'R_PYK_R41'
# set math on kinetic law for 'R_PYK_R41'
# create reaction for 'R_PYK_R42'
# set reaction id for 'R_PYK_R42'
# set reaction name for 'R_PYK_R42'
# set reaction reversible for 'R_PYK_R42'
# create specie reference M_pyk_R4_c for 'R_PYK_R42'
# set specie reference id for 'M_pyk_R4_c'
# set specie reference stoichiometry for 'M_pyk_R4_c'
# set specie reference constant for 'M_pyk_R4_c'
# create specie reference M_adp_c for 'R_PYK_R42'
# set specie reference id for 'M_adp_c'
# set specie reference stoichiometry for 'M_adp_c'
# set specie reference constant for 'M_adp_c'
# create specie reference M_pyk_R4_A_c for 'R_PYK_R42'
# set specie reference id for 'M_pyk_R4_A_c'
# set specie reference stoichiometry for 'M_pyk_R4_A_c'
# set specie reference constant for 'M_pyk_R4_A_c'
# get fbc plugin for reaction for 'R_PYK_R42'
# create kinetic law for 'R_PYK_R42'
# set math on kinetic law for 'R_PYK_R42'
# create reaction for 'R_PYK_R43'
# set reaction id for 'R_PYK_R43'
# set reaction name for 'R_PYK_R43'
# set reaction reversible for 'R_PYK_R43'
# create specie reference M_pyk_R4_A_c for 'R_PYK_R43'
# set specie reference id for 'M_pyk_R4_A_c'
# set specie reference stoichiometry for 'M_pyk_R4_A_c'
# set specie reference constant for 'M_pyk_R4_A_c'
# create specie reference M_pep_c for 'R_PYK_R43'
# set specie reference id for 'M_pep_c'
# set specie reference stoichiometry for 'M_pep_c'
# set specie reference constant for 'M_pep_c'
# create specie reference M_pyk_R4_AP_c for 'R_PYK_R43'
# set specie reference id for 'M_pyk_R4_AP_c'
# set specie reference stoichiometry for 'M_pyk_R4_AP_c'
# set specie reference constant for 'M_pyk_R4_AP_c'
# get fbc plugin for reaction for 'R_PYK_R43'
# create kinetic law for 'R_PYK_R43'
# set math on kinetic law for 'R_PYK_R43'
# create reaction for 'R_PYK_R44'
# set reaction id for 'R_PYK_R44'
# set reaction name for 'R_PYK_R44'
# set reaction reversible for 'R_PYK_R44'
# create specie reference M_pyk_R4_P_c for 'R_PYK_R44'
# set specie reference id for 'M_pyk_R4_P_c'
# set specie reference stoichiometry for 'M_pyk_R4_P_c'
# set specie reference constant for 'M_pyk_R4_P_c'
# create specie reference M_adp_c for 'R_PYK_R44'
# set specie reference id for 'M_adp_c'
# set specie reference stoichiometry for 'M_adp_c'
# set specie reference constant for 'M_adp_c'
# create specie reference M_pyk_R4_AP_c for 'R_PYK_R44'
# set specie reference id for 'M_pyk_R4_AP_c'
# set specie reference stoichiometry for 'M_pyk_R4_AP_c'
# set specie reference constant for 'M_pyk_R4_AP_c'
# get fbc plugin for reaction for 'R_PYK_R44'
# create kinetic law for 'R_PYK_R44'
# set math on kinetic law for 'R_PYK_R44'
# create reaction for 'R_PYK_R45'
# set reaction id for 'R_PYK_R45'
# set reaction name for 'R_PYK_R45'
# set reaction reversible for 'R_PYK_R45'
# create specie reference M_pyk_R4_AP_c for 'R_PYK_R45'
# set specie reference id for 'M_pyk_R4_AP_c'
# set specie reference stoichiometry for 'M_pyk_R4_AP_c'
# set specie reference constant for 'M_pyk_R4_AP_c'
# create specie reference M_h_c for 'R_PYK_R45'
# set specie reference id for 'M_h_c'
# set specie reference stoichiometry for 'M_h_c'
# set specie reference constant for 'M_h_c'
# create specie reference M_pyk_R4_c for 'R_PYK_R45'
# set specie reference id for 'M_pyk_R4_c'
# set specie reference stoichiometry for 'M_pyk_R4_c'
# set specie reference constant for 'M_pyk_R4_c'
# create specie reference M_atp_c for 'R_PYK_R45'
# set specie reference id for 'M_atp_c'
# set specie reference stoichiometry for 'M_atp_c'
# set specie reference constant for 'M_atp_c'
# create specie reference M_pyr_c for 'R_PYK_R45'
# set specie reference id for 'M_pyr_c'
# set specie reference stoichiometry for 'M_pyr_c'
# set specie reference constant for 'M_pyr_c'
# get fbc plugin for reaction for 'R_PYK_R45'
# create kinetic law for 'R_PYK_R45'
# set math on kinetic law for 'R_PYK_R45'
# create reaction for 'R_PYK_L'
# set reaction id for 'R_PYK_L'
# set reaction name for 'R_PYK_L'
# set reaction reversible for 'R_PYK_L'
# create specie reference M_pyk_R0_c for 'R_PYK_L'
# set specie reference id for 'M_pyk_R0_c'
# set specie reference stoichiometry for 'M_pyk_R0_c'
# set specie reference constant for 'M_pyk_R0_c'
# create specie reference M_pyk_T0_c for 'R_PYK_L'
# set specie reference id for 'M_pyk_T0_c'
# set specie reference stoichiometry for 'M_pyk_T0_c'
# set specie reference constant for 'M_pyk_T0_c'
# get fbc plugin for reaction for 'R_PYK_L'
# create kinetic law for 'R_PYK_L'
# set math on kinetic law for 'R_PYK_L'
# create reaction for 'R_PYK_T1'
# set reaction id for 'R_PYK_T1'
# set reaction name for 'R_PYK_T1'
# set reaction reversible for 'R_PYK_T1'
# create specie reference M_pyk_T0_c for 'R_PYK_T1'
# set specie reference id for 'M_pyk_T0_c'
# set specie reference stoichiometry for 'M_pyk_T0_c'
# set specie reference constant for 'M_pyk_T0_c'
# create specie reference M_atp_c for 'R_PYK_T1'
# set specie reference id for 'M_atp_c'
# set specie reference stoichiometry for 'M_atp_c'
# set specie reference constant for 'M_atp_c'
# create specie reference M_pyk_T1_c for 'R_PYK_T1'
# set specie reference id for 'M_pyk_T1_c'
# set specie reference stoichiometry for 'M_pyk_T1_c'
# set specie reference constant for 'M_pyk_T1_c'
# get fbc plugin for reaction for 'R_PYK_T1'
# create kinetic law for 'R_PYK_T1'
# set math on kinetic law for 'R_PYK_T1'
# create reaction for 'R_PYK_T2'
# set reaction id for 'R_PYK_T2'
# set reaction name for 'R_PYK_T2'
# set reaction reversible for 'R_PYK_T2'
# create specie reference M_pyk_T1_c for 'R_PYK_T2'
# set specie reference id for 'M_pyk_T1_c'
# set specie reference stoichiometry for 'M_pyk_T1_c'
# set specie reference constant for 'M_pyk_T1_c'
# create specie reference M_atp_c for 'R_PYK_T2'
# set specie reference id for 'M_atp_c'
# set specie reference stoichiometry for 'M_atp_c'
# set specie reference constant for 'M_atp_c'
# create specie reference M_pyk_T2_c for 'R_PYK_T2'
# set specie reference id for 'M_pyk_T2_c'
# set specie reference stoichiometry for 'M_pyk_T2_c'
# set specie reference constant for 'M_pyk_T2_c'
# get fbc plugin for reaction for 'R_PYK_T2'
# create kinetic law for 'R_PYK_T2'
# set math on kinetic law for 'R_PYK_T2'
# create reaction for 'R_PYK_T3'
# set reaction id for 'R_PYK_T3'
# set reaction name for 'R_PYK_T3'
# set reaction reversible for 'R_PYK_T3'
# create specie reference M_pyk_T2_c for 'R_PYK_T3'
# set specie reference id for 'M_pyk_T2_c'
# set specie reference stoichiometry for 'M_pyk_T2_c'
# set specie reference constant for 'M_pyk_T2_c'
# create specie reference M_atp_c for 'R_PYK_T3'
# set specie reference id for 'M_atp_c'
# set specie reference stoichiometry for 'M_atp_c'
# set specie reference constant for 'M_atp_c'
# create specie reference M_pyk_T3_c for 'R_PYK_T3'
# set specie reference id for 'M_pyk_T3_c'
# set specie reference stoichiometry for 'M_pyk_T3_c'
# set specie reference constant for 'M_pyk_T3_c'
# get fbc plugin for reaction for 'R_PYK_T3'
# create kinetic law for 'R_PYK_T3'
# set math on kinetic law for 'R_PYK_T3'
# create reaction for 'R_PYK_T4'
# set reaction id for 'R_PYK_T4'
# set reaction name for 'R_PYK_T4'
# set reaction reversible for 'R_PYK_T4'
# create specie reference M_pyk_T3_c for 'R_PYK_T4'
# set specie reference id for 'M_pyk_T3_c'
# set specie reference stoichiometry for 'M_pyk_T3_c'
# set specie reference constant for 'M_pyk_T3_c'
# create specie reference M_atp_c for 'R_PYK_T4'
# set specie reference id for 'M_atp_c'
# set specie reference stoichiometry for 'M_atp_c'
# set specie reference constant for 'M_atp_c'
# create specie reference M_pyk_T4_c for 'R_PYK_T4'
# set specie reference id for 'M_pyk_T4_c'
# set specie reference stoichiometry for 'M_pyk_T4_c'
# set specie reference constant for 'M_pyk_T4_c'
# get fbc plugin for reaction for 'R_PYK_T4'
# create kinetic law for 'R_PYK_T4'
# set math on kinetic law for 'R_PYK_T4'
#
# <?xml version="1.0" encoding="UTF-8"?>
# <sbml xmlns="http://www.sbml.org/sbml/level3/version2/core" xmlns:fbc="http://www.sbml.org/sbml/level3/version1/fbc/version2" sboTerm="SBO:0000062" level="3" version="2" fbc:required="false">
#   <model metaid="meta_PYK" id="PYK" name="Pyruvate Kinase" fbc:strict="false">
#     <listOfCompartments>
#       <compartment id="c" name="Cytosol" constant="true"/>
#     </listOfCompartments>
#     <listOfSpecies>
#       <species id="M_pep_c" name="Phosphoenolpyruvate" compartment="c" initialConcentration="0.017" hasOnlySubstanceUnits="false" boundaryCondition="false" constant="false" fbc:charge="-3" fbc:chemicalFormula="C3H2O6P"/>
#       <species id="M_adp_c" name="ADP" compartment="c" initialConcentration="0.29" hasOnlySubstanceUnits="false" boundaryCondition="false" constant="false" fbc:charge="-3" fbc:chemicalFormula="C10H12N5O10P2"/>
#       <species id="M_fdp_c" name="D-Fructose 1,6-bisphosphate" compartment="c" initialConcentration="0.0146" hasOnlySubstanceUnits="false" boundaryCondition="false" constant="false" fbc:charge="-4" fbc:chemicalFormula="C6H10O12P2"/>
#       <species id="M_atp_c" name="ATP" compartment="c" initialConcentration="1.6" hasOnlySubstanceUnits="false" boundaryCondition="false" constant="false" fbc:charge="-4" fbc:chemicalFormula="C10H12N5O13P3"/>
# ...
#               </apply>
#             </apply>
#           </math>
#         </kineticLaw>
#       </reaction>
#       <reaction id="R_PYK_R32" name="pyk_R3-adp binding" reversible="true">
#         <listOfReactants>
#           <speciesReference species="M_pyk_R3_c" stoichiometry="1" constant="false"/>
#           <speciesReference species="M_adp_c" stoichiometry="1" constant="false"/>
#         </listOfReactants>
#         <listOfProducts>
#           <speciesReference species="M_pyk_R3_A_c" stoichiometry="1" constant="false"/>
#         </listOfProducts>
#         <kineticLaw>
#           <math xmlns="http://www.w3.org/1998/Math/MathML">
#             <apply>
#               <times/>
#               <ci> kf_PYK_A </ci>
#               <apply>
#                 <minus/>
#                 <apply>
#                   <times/>
#                   <ci> M_adp_c </ci>
#                   <ci> M_pyk_R3_c </ci>
#                 </apply>
#                 <apply>
#                   <divide/>
#                   <ci> M_pyk_R3_A_c </ci>
#                   <ci> Keq_PYK_A </ci>
#                 </apply>
#               </apply>
#             </apply>
#           </math>
#         </kineticLaw>
#       </reaction>
#       <reaction id="R_PYK_R33" name="pyk_R3_A-pep binding" reversible="true">
#         <listOfReactants>
#           <speciesReference species="M_pyk_R3_A_c" stoichiometry="1" constant="false"/>
#           <speciesReference species="M_pep_c" stoichiometry="1" constant="false"/>
#         </listOfReactants>
#         <listOfProducts>
#           <speciesReference species="M_pyk_R3_AP_c" stoichiometry="1" constant="false"/>
#         </listOfProducts>
#         <kineticLaw>
#           <math xmlns="http://www.w3.org/1998/Math/MathML">
#             <apply>
#               <times/>
#               <ci> kf_PYK_P </ci>
#               <apply>
#                 <minus/>
#                 <apply>
#                   <times/>
#                   <ci> M_pep_c </ci>
#                   <ci> M_pyk_R3_A_c </ci>
#                 </apply>
#                 <apply>
#                   <divide/>
#                   <ci> M_pyk_R3_AP_c </ci>
#                   <ci> Keq_PYK_P </ci>
#                 </apply>
#               </apply>
#             </apply>
#           </math>
#         </kineticLaw>
#       </reaction>
#       <reaction id="R_PYK_R34" name="pyk_R3_P-adp binding" reversible="true">
#         <listOfReactants>
#           <speciesReference species="M_pyk_R3_P_c" stoichiometry="1" constant="false"/>
#           <speciesReference species="M_adp_c" stoichiometry="1" constant="false"/>
#         </listOfReactants>
#         <listOfProducts>
#           <speciesReference species="M_pyk_R3_AP_c" stoichiometry="1" constant="false"/>
#         </listOfProducts>
#         <kineticLaw>
#           <math xmlns="http://www.w3.org/1998/Math/MathML">
#             <apply>
#               <times/>
#               <ci> kf_PYK_A </ci>
#               <apply>
#                 <minus/>
#                 <apply>
#                   <times/>
#                   <ci> M_adp_c </ci>
#                   <ci> M_pyk_R3_P_c </ci>
#                 </apply>
#                 <apply>
#                   <divide/>
#                   <ci> M_pyk_R3_AP_c </ci>
#                   <ci> Keq_PYK_A </ci>
#                 </apply>
#               </apply>
#             </apply>
#           </math>
#         </kineticLaw>
#       </reaction>
#       <reaction id="R_PYK_R35" name="pyk_R3_AP catalyzation" reversible="false">
#         <listOfReactants>
#           <speciesReference species="M_pyk_R3_AP_c" stoichiometry="1" constant="false"/>
#           <speciesReference species="M_h_c" stoichiometry="1" constant="false"/>
#         </listOfReactants>
#         <listOfProducts>
#           <speciesReference species="M_pyk_R3_c" stoichiometry="1" constant="false"/>
#           <speciesReference species="M_atp_c" stoichiometry="1" constant="false"/>
#           <speciesReference species="M_pyr_c" stoichiometry="1" constant="false"/>
#         </listOfProducts>
#         <kineticLaw>
#           <math xmlns="http://www.w3.org/1998/Math/MathML">
#             <apply>
#               <times/>
#               <ci> M_pyk_R3_AP_c </ci>
#               <ci> kf_PYK </ci>
#             </apply>
#           </math>
#         </kineticLaw>
#       </reaction>
#       <reaction id="R_PYK_R40" name="pyk_R3-fdp binding" reversible="true">
#         <listOfReactants>
#           <speciesReference species="M_pyk_R3_c" stoichiometry="1" constant="false"/>
#           <speciesReference species="M_fdp_c" stoichiometry="1" constant="false"/>
#         </listOfReactants>
#         <listOfProducts>
#           <speciesReference species="M_pyk_R4_c" stoichiometry="1" constant="false"/>
#         </listOfProducts>
#         <kineticLaw>
#           <math xmlns="http://www.w3.org/1998/Math/MathML">
#             <apply>
#               <times/>
#               <ci> kf_PYK_ACT </ci>
#               <apply>
#                 <minus/>
#                 <apply>
#                   <times/>
#                   <ci> M_fdp_c </ci>
#                   <ci> M_pyk_R3_c </ci>
#                 </apply>
#                 <apply>
#                   <divide/>
#                   <apply>
#                     <times/>
#                     <cn> 4 </cn>
#                     <ci> M_pyk_R4_c </ci>
#                   </apply>
#                   <ci> Keq_PYK_ACT </ci>
#                 </apply>
#               </apply>
#             </apply>
#           </math>
#         </kineticLaw>
#       </reaction>
#       <reaction id="R_PYK_R41" name="pyk_R4-pep binding" reversible="true">
#         <listOfReactants>
#           <speciesReference species="M_pyk_R4_c" stoichiometry="1" constant="false"/>
#           <speciesReference species="M_pep_c" stoichiometry="1" constant="false"/>
#         </listOfReactants>
#         <listOfProducts>
#           <speciesReference species="M_pyk_R4_P_c" stoichiometry="1" constant="false"/>
#         </listOfProducts>
#         <kineticLaw>
#           <math xmlns="http://www.w3.org/1998/Math/MathML">
#             <apply>
#               <times/>
#               <ci> kf_PYK_P </ci>
#               <apply>
#                 <minus/>
#                 <apply>
#                   <times/>
#                   <ci> M_pep_c </ci>
#                   <ci> M_pyk_R4_c </ci>
#                 </apply>
#                 <apply>
#                   <divide/>
#                   <ci> M_pyk_R4_P_c </ci>
#                   <ci> Keq_PYK_P </ci>
#                 </apply>
#               </apply>
#             </apply>
#           </math>
#         </kineticLaw>
#       </reaction>
#       <reaction id="R_PYK_R42" name="pyk_R4-adp binding" reversible="true">
#         <listOfReactants>
#           <speciesReference species="M_pyk_R4_c" stoichiometry="1" constant="false"/>
#           <speciesReference species="M_adp_c" stoichiometry="1" constant="false"/>
#         </listOfReactants>
#         <listOfProducts>
#           <speciesReference species="M_pyk_R4_A_c" stoichiometry="1" constant="false"/>
#         </listOfProducts>
#         <kineticLaw>
#           <math xmlns="http://www.w3.org/1998/Math/MathML">
#             <apply>
#               <times/>
#               <ci> kf_PYK_A </ci>
#               <apply>
#                 <minus/>
#                 <apply>
#                   <times/>
#                   <ci> M_adp_c </ci>
#                   <ci> M_pyk_R4_c </ci>
#                 </apply>
#                 <apply>
#                   <divide/>
#                   <ci> M_pyk_R4_A_c </ci>
#                   <ci> Keq_PYK_A </ci>
#                 </apply>
#               </apply>
#             </apply>
#           </math>
#         </kineticLaw>
#       </reaction>
#       <reaction id="R_PYK_R43" name="pyk_R4_A-pep binding" reversible="true">
#         <listOfReactants>
#           <speciesReference species="M_pyk_R4_A_c" stoichiometry="1" constant="false"/>
#           <speciesReference species="M_pep_c" stoichiometry="1" constant="false"/>
#         </listOfReactants>
#         <listOfProducts>
#           <speciesReference species="M_pyk_R4_AP_c" stoichiometry="1" constant="false"/>
#         </listOfProducts>
#         <kineticLaw>
#           <math xmlns="http://www.w3.org/1998/Math/MathML">
#             <apply>
#               <times/>
#               <ci> kf_PYK_P </ci>
#               <apply>
#                 <minus/>
#                 <apply>
#                   <times/>
#                   <ci> M_pep_c </ci>
#                   <ci> M_pyk_R4_A_c </ci>
#                 </apply>
#                 <apply>
#                   <divide/>
#                   <ci> M_pyk_R4_AP_c </ci>
#                   <ci> Keq_PYK_P </ci>
#                 </apply>
#               </apply>
#             </apply>
#           </math>
#         </kineticLaw>
#       </reaction>
#       <reaction id="R_PYK_R44" name="pyk_R4_P-adp binding" reversible="true">
#         <listOfReactants>
#           <speciesReference species="M_pyk_R4_P_c" stoichiometry="1" constant="false"/>
#           <speciesReference species="M_adp_c" stoichiometry="1" constant="false"/>
#         </listOfReactants>
#         <listOfProducts>
#           <speciesReference species="M_pyk_R4_AP_c" stoichiometry="1" constant="false"/>
#         </listOfProducts>
#         <kineticLaw>
#           <math xmlns="http://www.w3.org/1998/Math/MathML">
#             <apply>
#               <times/>
#               <ci> kf_PYK_A </ci>
#               <apply>
#                 <minus/>
#                 <apply>
#                   <times/>
#                   <ci> M_adp_c </ci>
#                   <ci> M_pyk_R4_P_c </ci>
#                 </apply>
#                 <apply>
#                   <divide/>
#                   <ci> M_pyk_R4_AP_c </ci>
#                   <ci> Keq_PYK_A </ci>
#                 </apply>
#               </apply>
#             </apply>
#           </math>
#         </kineticLaw>
#       </reaction>
#       <reaction id="R_PYK_R45" name="pyk_R4_AP catalyzation" reversible="false">
#         <listOfReactants>
#           <speciesReference species="M_pyk_R4_AP_c" stoichiometry="1" constant="false"/>
#           <speciesReference species="M_h_c" stoichiometry="1" constant="false"/>
#         </listOfReactants>
#         <listOfProducts>
#           <speciesReference species="M_pyk_R4_c" stoichiometry="1" constant="false"/>
#           <speciesReference species="M_atp_c" stoichiometry="1" constant="false"/>
#           <speciesReference species="M_pyr_c" stoichiometry="1" constant="false"/>
#         </listOfProducts>
#         <kineticLaw>
#           <math xmlns="http://www.w3.org/1998/Math/MathML">
#             <apply>
#               <times/>
#               <ci> M_pyk_R4_AP_c </ci>
#               <ci> kf_PYK </ci>
#             </apply>
#           </math>
#         </kineticLaw>
#       </reaction>
#       <reaction id="R_PYK_L" name="pyk_R0-pyk_T0 transition" reversible="true">
#         <listOfReactants>
#           <speciesReference species="M_pyk_R0_c" stoichiometry="1" constant="false"/>
#         </listOfReactants>
#         <listOfProducts>
#           <speciesReference species="M_pyk_T0_c" stoichiometry="1" constant="false"/>
#         </listOfProducts>
#         <kineticLaw>
#           <math xmlns="http://www.w3.org/1998/Math/MathML">
#             <apply>
#               <times/>
#               <ci> kf_R_PYK_L </ci>
#               <apply>
#                 <minus/>
#                 <ci> M_pyk_R0_c </ci>
#                 <apply>
#                   <divide/>
#                   <ci> M_pyk_T0_c </ci>
#                   <ci> Keq_R_PYK_L </ci>
#                 </apply>
#               </apply>
#             </apply>
#           </math>
#         </kineticLaw>
#       </reaction>
#       <reaction id="R_PYK_T1" name="pyk_T0-atp binding" reversible="true">
#         <listOfReactants>
#           <speciesReference species="M_pyk_T0_c" stoichiometry="1" constant="false"/>
#           <speciesReference species="M_atp_c" stoichiometry="1" constant="false"/>
#         </listOfReactants>
#         <listOfProducts>
#           <speciesReference species="M_pyk_T1_c" stoichiometry="1" constant="false"/>
#         </listOfProducts>
#         <kineticLaw>
#           <math xmlns="http://www.w3.org/1998/Math/MathML">
#             <apply>
#               <times/>
#               <ci> kf_PYK_I </ci>
#               <apply>
#                 <minus/>
#                 <apply>
#                   <times/>
#                   <cn> 4 </cn>
#                   <ci> M_atp_c </ci>
#                   <ci> M_pyk_T0_c </ci>
#                 </apply>
#                 <apply>
#                   <divide/>
#                   <ci> M_pyk_T1_c </ci>
#                   <ci> Keq_PYK_I </ci>
#                 </apply>
#               </apply>
#             </apply>
#           </math>
#         </kineticLaw>
#       </reaction>
#       <reaction id="R_PYK_T2" name="pyk_T1-atp binding" reversible="true">
#         <listOfReactants>
#           <speciesReference species="M_pyk_T1_c" stoichiometry="1" constant="false"/>
#           <speciesReference species="M_atp_c" stoichiometry="1" constant="false"/>
#         </listOfReactants>
#         <listOfProducts>
#           <speciesReference species="M_pyk_T2_c" stoichiometry="1" constant="false"/>
#         </listOfProducts>
#         <kineticLaw>
#           <math xmlns="http://www.w3.org/1998/Math/MathML">
#             <apply>
#               <times/>
#               <ci> kf_PYK_I </ci>
#               <apply>
#                 <minus/>
#                 <apply>
#                   <times/>
#                   <cn> 3 </cn>
#                   <ci> M_atp_c </ci>
#                   <ci> M_pyk_T1_c </ci>
#                 </apply>
#                 <apply>
#                   <divide/>
#                   <apply>
#                     <times/>
#                     <cn> 2 </cn>
#                     <ci> M_pyk_T2_c </ci>
#                   </apply>
#                   <ci> Keq_PYK_I </ci>
#                 </apply>
#               </apply>
#             </apply>
#           </math>
#         </kineticLaw>
#       </reaction>
#       <reaction id="R_PYK_T3" name="pyk_T2-atp binding" reversible="true">
#         <listOfReactants>
#           <speciesReference species="M_pyk_T2_c" stoichiometry="1" constant="false"/>
#           <speciesReference species="M_atp_c" stoichiometry="1" constant="false"/>
#         </listOfReactants>
#         <listOfProducts>
#           <speciesReference species="M_pyk_T3_c" stoichiometry="1" constant="false"/>
#         </listOfProducts>
#         <kineticLaw>
#           <math xmlns="http://www.w3.org/1998/Math/MathML">
#             <apply>
#               <times/>
#               <ci> kf_PYK_I </ci>
#               <apply>
#                 <minus/>
#                 <apply>
#                   <times/>
#                   <cn> 2 </cn>
#                   <ci> M_atp_c </ci>
#                   <ci> M_pyk_T2_c </ci>
#                 </apply>
#                 <apply>
#                   <divide/>
#                   <apply>
#                     <times/>
#                     <cn> 3 </cn>
#                     <ci> M_pyk_T3_c </ci>
#                   </apply>
#                   <ci> Keq_PYK_I </ci>
#                 </apply>
#               </apply>
#             </apply>
#           </math>
#         </kineticLaw>
#       </reaction>
#       <reaction id="R_PYK_T4" name="pyk_T3-atp binding" reversible="true">
#         <listOfReactants>
#           <speciesReference species="M_pyk_T3_c" stoichiometry="1" constant="false"/>
#           <speciesReference species="M_atp_c" stoichiometry="1" constant="false"/>
#         </listOfReactants>
#         <listOfProducts>
#           <speciesReference species="M_pyk_T4_c" stoichiometry="1" constant="false"/>
#         </listOfProducts>
#         <kineticLaw>
#           <math xmlns="http://www.w3.org/1998/Math/MathML">
#             <apply>
#               <times/>
#               <ci> kf_PYK_I </ci>
#               <apply>
#                 <minus/>
#                 <apply>
#                   <times/>
#                   <ci> M_atp_c </ci>
#                   <ci> M_pyk_T3_c </ci>
#                 </apply>
#                 <apply>
#                   <divide/>
#                   <apply>
#                     <times/>
#                     <cn> 4 </cn>
#                     <ci> M_pyk_T4_c </ci>
#                   </apply>
#                   <ci> Keq_PYK_I </ci>
#                 </apply>
#               </apply>
#             </apply>
#           </math>
#         </kineticLaw>
#       </reaction>
#     </listOfReactions>
#   </model>
# </sbml>
